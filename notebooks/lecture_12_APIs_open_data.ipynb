# %% [markdown]
# # CYPLAN255
# ### Urban Informatics and Visualization

# %% [markdown]
# HIT RECORD and TRANSCRIBE

# %% [markdown]
# # Lecture 12 -- APIs and Beyond <img src="https://i.imgur.com/HMHNjAq.jpg" width=550 align='right' title="Scottish child actress, Binkie Stuart (1932 - 2001) hand in hand with a penguin during a visit to London Zoo, 15th April 1937. (Photo by Fox Photos/Hulton Archive/Getty Images)">
# ******
# March 7, 2022

# %% [markdown]
# # Agenda
# 1. Announcements
# 2. Review: APIs + JSON
# 2. Geocoding APIs
# 3. The Census API
# 4. Summary
# 5. For next time
# 6. Questions

# %% [markdown]
# # 1. Announcements

# %% [markdown]
# - Assignment 4 (project proposal + initial analysis) due March 13
# - Final Project description released tonight
# - Irene's GitHub Pages tutorial posted on bCourses under `Files > Recordings > mar_03`
# - How far we've come

# %% [markdown]
# ## How Far We've Come
#
# 1. ~Fundamentals of Programming~
# 1. ~Intro to Data Analysis in Python~
# 1. ~Intro to Data Visualization~
# 1. APIs + Open Data
# 1. Working with Geospatial Data
# 1. Visualizing Spatial Data
# 1. Statistical Analysis + Machine Learning

# %% [markdown]
# # 2. Review: APIs + JSON

# %% [markdown]
# So far we've seen how you can use an API to download data stored as a .json file in some static location. That's cool, but ultimately not that different from clicking a link and downloading a file to your desktop. It also presumes you know the URL you want ahead of time, and that you want to download the entire file.
#
# Today we're going to be seeing how you can use APIs to interact with _services_, i.e. APIs that perform operations and generate the data you want on demand. To continue with the restaurant analogy, we started off ordering fast food burgers, but now we're ready for the tasting menu at Chez Panisse.

# %% [markdown]
# <img src="https://i.kym-cdn.com/photos/images/original/001/474/943/b12.jpg" width=200 align="right">

# %% [markdown]
# But before we get there, let's quickly review what we've learned so far by checking out the USGS real-time earthquake data API.
#
# ### 2.1. USGS real-time earthquake feeds
#
# This is an API for near-real-time data about earthquakes. Data is provided in JSON format over the web. No authentication is needed, and there's no way to customize the output. Instead, the API has a separate endpoint for each permutation of the data that users might want.
#
# **API documentation:**
# http://earthquake.usgs.gov/earthquakes/feed/v1.0/geojson.php
#
# **Sample API endpoint, for magnitude 4.5+ earthquakes in past day:**
# http://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/4.5_day.geojson

# %% [markdown]
# We'll start by querying the endpoint for magnitude 2.5+ quakes from the past week:

# %%
import pandas as pd
import json    
import requests
import pprint
pp = pprint.PrettyPrinter

endpoint_url = "http://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/2.5_week.geojson"
response = requests.get(endpoint_url)
print(response.text[:500])
# Out:
# {"type":"FeatureCollection","metadata":{"generated":1646675329000,"url":"https://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/2.5_week.geojson","title":"USGS Magnitude 2.5+ Earthquakes, Past Week","status":200,"api":"1.10.3","count":286},"features":[{"type":"Feature","properties":{"mag":4.9,"place":"243 km W of Tual, Indonesia","time":1646673829778,"updated":1646674893040,"tz":null,"url":"https://earthquake.usgs.gov/earthquakes/eventpage/us6000h2sf","detail":"https://earthquake.usgs.gov/ear

# %% [markdown]
# It looks like the results are a string with JSON-formatted data inside, so we'll parse the string into a Python dictionary using `json.loads()`:

# %%
data = json.loads(response.text)
data
# Out:
# {'type': 'FeatureCollection',
#  'metadata': {'generated': 1646675329000,
#   'url': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/2.5_week.geojson',
#   'title': 'USGS Magnitude 2.5+ Earthquakes, Past Week',
#   'status': 200,
#   'api': '1.10.3',
#   'count': 286},
#  'features': [{'type': 'Feature',
#    'properties': {'mag': 4.9,
#     'place': '243 km W of Tual, Indonesia',
#     'time': 1646673829778,
#     'updated': 1646674893040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h2sf',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h2sf.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 369,
#     'net': 'us',
#     'code': '6000h2sf',
#     'ids': ',us6000h2sf,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 2.158,
#     'rms': 0.76,
#     'gap': 47,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.9 - 243 km W of Tual, Indonesia'},
#    'geometry': {'type': 'Point', 'coordinates': [130.5771, -5.9336, 132.38]},
#    'id': 'us6000h2sf'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.8,
#     'place': '58 km NNE of Nanao, Japan',
#     'time': 1646672328869,
#     'updated': 1646674777040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h2s5',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h2s5.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 354,
#     'net': 'us',
#     'code': '6000h2s5',
#     'ids': ',us6000h2s5,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 1.224,
#     'rms': 0.6,
#     'gap': 88,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 4.8 - 58 km NNE of Nanao, Japan'},
#    'geometry': {'type': 'Point', 'coordinates': [137.2733, 37.5197, 4.76]},
#    'id': 'us6000h2s5'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.7,
#     'place': '35 km SSW of Los Ybanez, Texas',
#     'time': 1646672217284,
#     'updated': 1646674649040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/tx2022eqbg',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/tx2022eqbg.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 112,
#     'net': 'tx',
#     'code': '2022eqbg',
#     'ids': ',us6000h2s1,tx2022eqbg,',
#     'sources': ',us,tx,',
#     'types': ',origin,phase-data,',
#     'nst': 10,
#     'dmin': 0.2355105413,
#     'rms': 0.1,
#     'gap': 68,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.7 - 35 km SSW of Los Ybanez, Texas'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-102.0785299, 32.42706299, 7.60542806]},
#    'id': 'tx2022eqbg'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.34,
#     'place': '66 km N of Charlotte Amalie, U.S. Virgin Islands',
#     'time': 1646672076600,
#     'updated': 1646674506040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr71339393',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr71339393.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 172,
#     'net': 'pr',
#     'code': '71339393',
#     'ids': ',us6000h2sc,pr71339393,',
#     'sources': ',us,pr,',
#     'types': ',origin,phase-data,',
#     'nst': 6,
#     'dmin': None,
#     'rms': 0.24,
#     'gap': 318,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 3.3 - 66 km N of Charlotte Amalie, U.S. Virgin Islands'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-65.0133333333333, 18.9413333333333, 15.96]},
#    'id': 'pr71339393'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.54,
#     'place': '6km WNW of Bodie, CA',
#     'time': 1646670162910,
#     'updated': 1646675219746,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73702486',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc73702486.geojson',
#     'felt': 11,
#     'cdi': 3.4,
#     'mmi': 3.308,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 197,
#     'net': 'nc',
#     'code': '73702486',
#     'ids': ',nc73702486,us6000h2rw,nn00835007,',
#     'sources': ',nc,us,nn,',
#     'types': ',dyfi,focal-mechanism,moment-tensor,nearby-cities,origin,phase-data,scitech-link,shakemap,',
#     'nst': 50,
#     'dmin': 0.3079,
#     'rms': 0.18,
#     'gap': 94,
#     'magType': 'mw',
#     'type': 'earthquake',
#     'title': 'M 3.5 - 6km WNW of Bodie, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-119.0830002, 38.2228317, 13.85]},
#    'id': 'nc73702486'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.48,
#     'place': '11 km ENE of Pāhala, Hawaii',
#     'time': 1646666434530,
#     'updated': 1646666786040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv72941532',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/hv72941532.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 95,
#     'net': 'hv',
#     'code': '72941532',
#     'ids': ',us6000h2rh,hv72941532,',
#     'sources': ',us,hv,',
#     'types': ',origin,phase-data,',
#     'nst': 44,
#     'dmin': None,
#     'rms': 0.140000001,
#     'gap': 154,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.5 - 11 km ENE of Pāhala, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.370498657227, 19.228666305542, 32.1399993896484]},
#    'id': 'hv72941532'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.8,
#     'place': '106 km WSW of Wuwei, China',
#     'time': 1646663728233,
#     'updated': 1646666216040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h2r6',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h2r6.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 354,
#     'net': 'us',
#     'code': '6000h2r6',
#     'ids': ',us6000h2r6,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 10.725,
#     'rms': 0.39,
#     'gap': 53,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.8 - 106 km WSW of Wuwei, China'},
#    'geometry': {'type': 'Point', 'coordinates': [101.4456, 37.7354, 10]},
#    'id': 'us6000h2r6'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.49,
#     'place': '5 km S of Pāhala, Hawaii',
#     'time': 1646660129060,
#     'updated': 1646662854040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv72941427',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/hv72941427.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 95,
#     'net': 'hv',
#     'code': '72941427',
#     'ids': ',us6000h2r1,hv72941427,',
#     'sources': ',us,hv,',
#     'types': ',origin,phase-data,',
#     'nst': 46,
#     'dmin': None,
#     'rms': 0.180000007,
#     'gap': 168,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.5 - 5 km S of Pāhala, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.471664428711, 19.1504993438721, 30.5499992370605]},
#    'id': 'hv72941427'},
#   {'type': 'Feature',
#    'properties': {'mag': 3,
#     'place': '10 km SSE of Gardendale, Texas',
#     'time': 1646656723125,
#     'updated': 1646667303978,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/tx2022epss',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/tx2022epss.geojson',
#     'felt': 29,
#     'cdi': 3.6,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 149,
#     'net': 'tx',
#     'code': '2022epss',
#     'ids': ',us6000h2qw,tx2022epss,',
#     'sources': ',us,tx,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': 17,
#     'dmin': 0.01704437691,
#     'rms': 0.2,
#     'gap': 58,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 3.0 - 10 km SSE of Gardendale, Texas'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-102.34113, 31.9354248, 7.189697265999999]},
#    'id': 'tx2022epss'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.74,
#     'place': '9 km SSE of Maria Antonia, Puerto Rico',
#     'time': 1646656283430,
#     'updated': 1646658944680,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr71339368',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr71339368.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 116,
#     'net': 'pr',
#     'code': '71339368',
#     'ids': ',pr71339368,',
#     'sources': ',pr,',
#     'types': ',origin,phase-data,',
#     'nst': 5,
#     'dmin': None,
#     'rms': 0.25,
#     'gap': 235,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.7 - 9 km SSE of Maria Antonia, Puerto Rico'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-66.8578333333333, 17.9015, 11.67]},
#    'id': 'pr71339368'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.9,
#     'place': '99 km S of Kushiro, Japan',
#     'time': 1646647762271,
#     'updated': 1646650599040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h2qh',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h2qh.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 369,
#     'net': 'us',
#     'code': '6000h2qh',
#     'ids': ',us6000h2qh,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 0.939,
#     'rms': 0.86,
#     'gap': 98,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.9 - 99 km S of Kushiro, Japan'},
#    'geometry': {'type': 'Point', 'coordinates': [144.4153, 42.0785, 10]},
#    'id': 'us6000h2qh'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.41000009,
#     'place': '4 km SSE of Pāhala, Hawaii',
#     'time': 1646640454610,
#     'updated': 1646672475070,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv72941132',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/hv72941132.geojson',
#     'felt': 8,
#     'cdi': 3.4,
#     'mmi': 3.794,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 182,
#     'net': 'hv',
#     'code': '72941132',
#     'ids': ',hv72941132,us6000h2q0,',
#     'sources': ',hv,us,',
#     'types': ',dyfi,origin,phase-data,shakemap,',
#     'nst': 46,
#     'dmin': None,
#     'rms': 0.129999995,
#     'gap': 93,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 3.4 - 4 km SSE of Pāhala, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.469329833984, 19.1616668701172, 32.1199989318848]},
#    'id': 'hv72941132'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.72,
#     'place': '1 km SE of Indios, Puerto Rico',
#     'time': 1646636057140,
#     'updated': 1646641146020,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr71339338',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr71339338.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 114,
#     'net': 'pr',
#     'code': '71339338',
#     'ids': ',pr71339338,',
#     'sources': ',pr,',
#     'types': ',origin,phase-data,',
#     'nst': 11,
#     'dmin': None,
#     'rms': 0.1,
#     'gap': 177,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.7 - 1 km SE of Indios, Puerto Rico'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-66.8076666666667, 17.9808333333333, 14.69]},
#    'id': 'pr71339338'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.4,
#     'place': '29 km NNW of Labuan Lombok, Indonesia',
#     'time': 1646635057564,
#     'updated': 1646639430040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h2pn',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h2pn.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 298,
#     'net': 'us',
#     'code': '6000h2pn',
#     'ids': ',us6000h2pn,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 1.31,
#     'rms': 0.54,
#     'gap': 76,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.4 - 29 km NNW of Labuan Lombok, Indonesia'},
#    'geometry': {'type': 'Point', 'coordinates': [116.5855, -8.2488, 10]},
#    'id': 'us6000h2pn'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.34,
#     'place': '4 km WSW of Pāhala, Hawaii',
#     'time': 1646634492490,
#     'updated': 1646674085973,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv72941037',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/hv72941037.geojson',
#     'felt': 28,
#     'cdi': 3.4,
#     'mmi': 3.661,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 181,
#     'net': 'hv',
#     'code': '72941037',
#     'ids': ',hv72941037,us6000h2pg,',
#     'sources': ',hv,us,',
#     'types': ',dyfi,origin,phase-data,shakemap,',
#     'nst': 45,
#     'dmin': None,
#     'rms': 0.09,
#     'gap': 96,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 3.3 - 4 km WSW of Pāhala, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.514, 19.1843333333333, 36.07]},
#    'id': 'hv72941037'},
#   {'type': 'Feature',
#    'properties': {'mag': 6.1,
#     'place': 'Fiji region',
#     'time': 1646631258630,
#     'updated': 1646673531040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h2nu',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h2nu.geojson',
#     'felt': 1,
#     'cdi': 1,
#     'mmi': 2.167,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 573,
#     'net': 'us',
#     'code': '6000h2nu',
#     'ids': ',us6000h2nu,',
#     'sources': ',us,',
#     'types': ',dyfi,ground-failure,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 4.233,
#     'rms': 1.15,
#     'gap': 19,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.1 - Fiji region'},
#    'geometry': {'type': 'Point', 'coordinates': [-178.4313, -20.3797, 581.81]},
#    'id': 'us6000h2nu'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.17,
#     'place': '35 km WSW of Pole Ojea, Puerto Rico',
#     'time': 1646629652750,
#     'updated': 1646630926570,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr71339323',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr71339323.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 155,
#     'net': 'pr',
#     'code': '71339323',
#     'ids': ',pr71339323,',
#     'sources': ',pr,',
#     'types': ',origin,phase-data,',
#     'nst': 8,
#     'dmin': None,
#     'rms': 0.12,
#     'gap': 312,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 3.2 - 35 km WSW of Pole Ojea, Puerto Rico'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-67.508, 17.8898333333333, 16.3]},
#    'id': 'pr71339323'},
#   {'type': 'Feature',
#    'properties': {'mag': 3,
#     'place': '55 km S of Whites City, New Mexico',
#     'time': 1646627914926,
#     'updated': 1646628850674,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/tx2022epcw',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/tx2022epcw.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 138,
#     'net': 'tx',
#     'code': '2022epcw',
#     'ids': ',us6000h2nm,tx2022epcw,',
#     'sources': ',us,tx,',
#     'types': ',origin,phase-data,',
#     'nst': 16,
#     'dmin': 0.07616940801,
#     'rms': 0.2,
#     'gap': 58,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 3.0 - 55 km S of Whites City, New Mexico'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-104.4115769, 31.67305826, 6.362939453]},
#    'id': 'tx2022epcw'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.5,
#     'place': '3 km SW of Indios, Puerto Rico',
#     'time': 1646625558800,
#     'updated': 1646626112830,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr71339313',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr71339313.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 96,
#     'net': 'pr',
#     'code': '71339313',
#     'ids': ',pr71339313,',
#     'sources': ',pr,',
#     'types': ',origin,phase-data,',
#     'nst': 8,
#     'dmin': None,
#     'rms': 0.08,
#     'gap': 198,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.5 - 3 km SW of Indios, Puerto Rico'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-66.8411666666667, 17.9725, 14.02]},
#    'id': 'pr71339313'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.8,
#     'place': '180 km W of Ferndale, California',
#     'time': 1646623466713,
#     'updated': 1646674990489,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h2nc',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h2nc.geojson',
#     'felt': 1,
#     'cdi': 2,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 121,
#     'net': 'us',
#     'code': '6000h2nc',
#     'ids': ',us6000h2nc,',
#     'sources': ',us,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': None,
#     'dmin': 1.721,
#     'rms': 0.27,
#     'gap': 284,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.8 - 180 km W of Ferndale, California'},
#    'geometry': {'type': 'Point', 'coordinates': [-126.3753, 40.4037, 7.76]},
#    'id': 'us6000h2nc'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.6,
#     'place': '49 km N of Punta Cana, Dominican Republic',
#     'time': 1646622741094,
#     'updated': 1646624095040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h2na',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h2na.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 104,
#     'net': 'us',
#     'code': '6000h2na',
#     'ids': ',us6000h2na,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 0.512,
#     'rms': 0.6,
#     'gap': 188,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.6 - 49 km N of Punta Cana, Dominican Republic'},
#    'geometry': {'type': 'Point', 'coordinates': [-68.341, 19.0281, 9.21]},
#    'id': 'us6000h2na'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.1,
#     'place': '150 km W of Haines Junction, Canada',
#     'time': 1646618431978,
#     'updated': 1646667846553,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h2mz',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h2mz.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 148,
#     'net': 'us',
#     'code': '6000h2mz',
#     'ids': ',ak022316nu9j,us6000h2mz,',
#     'sources': ',ak,us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 0.401,
#     'rms': 1.05,
#     'gap': 113,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 3.1 - 150 km W of Haines Junction, Canada'},
#    'geometry': {'type': 'Point', 'coordinates': [-140.2424, 60.9718, 5]},
#    'id': 'us6000h2mz'},
#   {'type': 'Feature',
#    'properties': {'mag': 5,
#     'place': 'Mid-Indian Ridge',
#     'time': 1646618260039,
#     'updated': 1646619606040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h2n0',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h2n0.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 385,
#     'net': 'us',
#     'code': '6000h2n0',
#     'ids': ',us6000h2n0,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 12.354,
#     'rms': 1.16,
#     'gap': 115,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 5.0 - Mid-Indian Ridge'},
#    'geometry': {'type': 'Point', 'coordinates': [66.1569, -13.7855, 10]},
#    'id': 'us6000h2n0'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.2,
#     'place': '30 km WSW of Orcopampa, Peru',
#     'time': 1646618053509,
#     'updated': 1646620660040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h2mv',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h2mv.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 271,
#     'net': 'us',
#     'code': '6000h2mv',
#     'ids': ',us6000h2mv,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 3.721,
#     'rms': 1.31,
#     'gap': 129,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.2 - 30 km WSW of Orcopampa, Peru'},
#    'geometry': {'type': 'Point', 'coordinates': [-72.603, -15.3699, 120.04]},
#    'id': 'us6000h2mv'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.4,
#     'place': '21 km SW of Pogradec, Albania',
#     'time': 1646617294658,
#     'updated': 1646618918040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h2ms',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h2ms.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 298,
#     'net': 'us',
#     'code': '6000h2ms',
#     'ids': ',us6000h2ms,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 0.73,
#     'rms': 1.14,
#     'gap': 44,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.4 - 21 km SW of Pogradec, Albania'},
#    'geometry': {'type': 'Point', 'coordinates': [20.4665, 40.7766, 10]},
#    'id': 'us6000h2ms'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.4,
#     'place': '96 km ESE of Ishinomaki, Japan',
#     'time': 1646616855192,
#     'updated': 1646618694040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h2mt',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h2mt.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 298,
#     'net': 'us',
#     'code': '6000h2mt',
#     'ids': ',us6000h2mt,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 2.955,
#     'rms': 0.83,
#     'gap': 146,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.4 - 96 km ESE of Ishinomaki, Japan'},
#    'geometry': {'type': 'Point', 'coordinates': [142.2513, 37.9771, 36.56]},
#    'id': 'us6000h2mt'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.4,
#     'place': '38 km SW of Turt, Mongolia',
#     'time': 1646610978033,
#     'updated': 1646612055040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h2md',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h2md.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 298,
#     'net': 'us',
#     'code': '6000h2md',
#     'ids': ',us6000h2md,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 2.171,
#     'rms': 0.65,
#     'gap': 42,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.4 - 38 km SW of Turt, Mongolia'},
#    'geometry': {'type': 'Point', 'coordinates': [100.2288, 51.2856, 10]},
#    'id': 'us6000h2md'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.7,
#     'place': '56 km S of Whites City, New Mexico',
#     'time': 1646608258759,
#     'updated': 1646609965040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h2m9',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h2m9.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 112,
#     'net': 'us',
#     'code': '6000h2m9',
#     'ids': ',us6000h2m9,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 0.144,
#     'rms': 1,
#     'gap': 68,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.7 - 56 km S of Whites City, New Mexico'},
#    'geometry': {'type': 'Point', 'coordinates': [-104.331, 31.6702, 5]},
#    'id': 'us6000h2m9'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.8,
#     'place': '229 km N of Inuvik, Canada',
#     'time': 1646603651162,
#     'updated': 1646605175040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h2lu',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h2lu.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 354,
#     'net': 'us',
#     'code': '6000h2lu',
#     'ids': ',us6000h2lu,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 2.132,
#     'rms': 0.77,
#     'gap': 77,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.8 - 229 km N of Inuvik, Canada'},
#    'geometry': {'type': 'Point', 'coordinates': [-134.4761, 70.4013, 10]},
#    'id': 'us6000h2lu'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.2,
#     'place': 'Philippine Islands region',
#     'time': 1646603286659,
#     'updated': 1646604078040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h2lt',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h2lt.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 271,
#     'net': 'us',
#     'code': '6000h2lt',
#     'ids': ',us6000h2lt,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 2.803,
#     'rms': 0.47,
#     'gap': 169,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.2 - Philippine Islands region'},
#    'geometry': {'type': 'Point', 'coordinates': [127.5289, 5.0319, 107.42]},
#    'id': 'us6000h2lt'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.2,
#     'place': '36 km ESE of Farkhār, Afghanistan',
#     'time': 1646602258853,
#     'updated': 1646603091040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h2ls',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h2ls.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 271,
#     'net': 'us',
#     'code': '6000h2ls',
#     'ids': ',us6000h2ls,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 0.687,
#     'rms': 0.78,
#     'gap': 125,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.2 - 36 km ESE of Farkhār, Afghanistan'},
#    'geometry': {'type': 'Point', 'coordinates': [70.2509, 36.4886, 207]},
#    'id': 'us6000h2ls'},
#   {'type': 'Feature',
#    'properties': {'mag': 3,
#     'place': 'Fox Islands, Aleutian Islands, Alaska',
#     'time': 1646600169036,
#     'updated': 1646602883040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h2lr',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h2lr.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 138,
#     'net': 'us',
#     'code': '6000h2lr',
#     'ids': ',us6000h2lr,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 0.104,
#     'rms': 0.26,
#     'gap': 173,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 3.0 - Fox Islands, Aleutian Islands, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-165.9049, 54.0667, 104.16]},
#    'id': 'us6000h2lr'},
#   {'type': 'Feature',
#    'properties': {'mag': 6,
#     'place': 'South Sandwich Islands region',
#     'time': 1646597670463,
#     'updated': 1646605099584,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h2l5',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h2l5.geojson',
#     'felt': 1,
#     'cdi': 1,
#     'mmi': 3.732,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 554,
#     'net': 'us',
#     'code': '6000h2l5',
#     'ids': ',us6000h2l5,',
#     'sources': ',us,',
#     'types': ',dyfi,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 7.812,
#     'rms': 1.51,
#     'gap': 31,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.0 - South Sandwich Islands region'},
#    'geometry': {'type': 'Point', 'coordinates': [-24.8859, -58.7354, 15.48]},
#    'id': 'us6000h2l5'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.1,
#     'place': '99 km W of San Antonio de los Cobres, Argentina',
#     'time': 1646596947872,
#     'updated': 1646603630040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h2l2',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h2l2.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 259,
#     'net': 'us',
#     'code': '6000h2l2',
#     'ids': ',us6000h2l2,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 1.575,
#     'rms': 0.85,
#     'gap': 84,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.1 - 99 km W of San Antonio de los Cobres, Argentina'},
#    'geometry': {'type': 'Point', 'coordinates': [-67.2942, -24.3084, 200.46]},
#    'id': 'us6000h2l2'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.1,
#     'place': '129 km E of San Pedro de Atacama, Chile',
#     'time': 1646586625433,
#     'updated': 1646604188040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h2kc',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h2kc.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 259,
#     'net': 'us',
#     'code': '6000h2kc',
#     'ids': ',us6000h2kc,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 1.135,
#     'rms': 0.98,
#     'gap': 98,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.1 - 129 km E of San Pedro de Atacama, Chile'},
#    'geometry': {'type': 'Point', 'coordinates': [-66.9608, -23.1239, 233]},
#    'id': 'us6000h2kc'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.6,
#     'place': '51 km E of Pedro Bay, Alaska',
#     'time': 1646585947518,
#     'updated': 1646588800040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0222zrt5j3',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak0222zrt5j3.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 104,
#     'net': 'ak',
#     'code': '0222zrt5j3',
#     'ids': ',us6000h2ka,ak0222zrt5j3,',
#     'sources': ',us,ak,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.64,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.6 - 51 km E of Pedro Bay, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-153.1856, 59.7535, 104]},
#    'id': 'ak0222zrt5j3'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.15,
#     'place': '140 km N of Cruz Bay, U.S. Virgin Islands',
#     'time': 1646583615850,
#     'updated': 1646597884699,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr2022065000',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr2022065000.geojson',
#     'felt': 1,
#     'cdi': 2,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 265,
#     'net': 'pr',
#     'code': '2022065000',
#     'ids': ',pr2022065000,us6000h2jt,',
#     'sources': ',pr,us,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': 30,
#     'dmin': 1.4075,
#     'rms': 0.4,
#     'gap': 237,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 4.2 - 140 km N of Cruz Bay, U.S. Virgin Islands'},
#    'geometry': {'type': 'Point', 'coordinates': [-64.7268, 19.6006, 30]},
#    'id': 'pr2022065000'},
#   {'type': 'Feature',
#    'properties': {'mag': 4,
#     'place': '24 km WNW of Pucara, Peru',
#     'time': 1646574151864,
#     'updated': 1646577138040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h2jf',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h2jf.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 246,
#     'net': 'us',
#     'code': '6000h2jf',
#     'ids': ',us6000h2jf,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 2.685,
#     'rms': 0.28,
#     'gap': 128,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.0 - 24 km WNW of Pucara, Peru'},
#    'geometry': {'type': 'Point', 'coordinates': [-71.672, -15.9071, 156.78]},
#    'id': 'us6000h2jf'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.4,
#     'place': '77 km NNE of Ruteng, Indonesia',
#     'time': 1646568430925,
#     'updated': 1646569409040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h2j5',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h2j5.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 298,
#     'net': 'us',
#     'code': '6000h2j5',
#     'ids': ',us6000h2j5,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 1.697,
#     'rms': 0.61,
#     'gap': 97,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.4 - 77 km NNE of Ruteng, Indonesia'},
#    'geometry': {'type': 'Point', 'coordinates': [120.6695, -7.9437, 10]},
#    'id': 'us6000h2j5'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.9,
#     'place': '21 km NNE of Skwentna, Alaska',
#     'time': 1646567639143,
#     'updated': 1646654258973,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0222zost6b',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak0222zost6b.geojson',
#     'felt': 11,
#     'cdi': 3.4,
#     'mmi': 2.671,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 238,
#     'net': 'ak',
#     'code': '0222zost6b',
#     'ids': ',ak0222zost6b,us6000h2j3,',
#     'sources': ',ak,us,',
#     'types': ',dyfi,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.51,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 3.9 - 21 km NNE of Skwentna, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-151.2083, 62.1566, 70.3]},
#    'id': 'ak0222zost6b'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.74,
#     'place': '3 km S of Pāhala, Hawaii',
#     'time': 1646566777090,
#     'updated': 1646567450040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv72940012',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/hv72940012.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 116,
#     'net': 'hv',
#     'code': '72940012',
#     'ids': ',us6000h2iz,hv72940012,',
#     'sources': ',us,hv,',
#     'types': ',origin,phase-data,',
#     'nst': 51,
#     'dmin': None,
#     'rms': 0.119999997,
#     'gap': 92,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.7 - 3 km S of Pāhala, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.482666015625, 19.1698341369629, 34.3600006103516]},
#    'id': 'hv72940012'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.5,
#     'place': '64 km WNW of Vinchina, Argentina',
#     'time': 1646559307155,
#     'updated': 1646645945510,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h2il',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h2il.geojson',
#     'felt': 2,
#     'cdi': 3.8,
#     'mmi': 3.809,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 466,
#     'net': 'us',
#     'code': '6000h2il',
#     'ids': ',us6000h2il,',
#     'sources': ',us,',
#     'types': ',dyfi,losspager,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 1.575,
#     'rms': 0.98,
#     'gap': 41,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 5.5 - 64 km WNW of Vinchina, Argentina'},
#    'geometry': {'type': 'Point', 'coordinates': [-68.8277, -28.5653, 118.26]},
#    'id': 'us6000h2il'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.6,
#     'place': 'Lake Edward region, Uganda',
#     'time': 1646557189445,
#     'updated': 1646561153451,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h2ih',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h2ih.geojson',
#     'felt': 2,
#     'cdi': 3.1,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 326,
#     'net': 'us',
#     'code': '6000h2ih',
#     'ids': ',us6000h2ih,',
#     'sources': ',us,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': None,
#     'dmin': 1.019,
#     'rms': 0.29,
#     'gap': 80,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.6 - Lake Edward region, Uganda'},
#    'geometry': {'type': 'Point', 'coordinates': [29.8224, -0.1512, 10]},
#    'id': 'us6000h2ih'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.1,
#     'place': 'Kermadec Islands region',
#     'time': 1646549825254,
#     'updated': 1646551302040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h2hv',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h2hv.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 400,
#     'net': 'us',
#     'code': '6000h2hv',
#     'ids': ',us6000h2hv,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 7.927,
#     'rms': 1.14,
#     'gap': 43,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 5.1 - Kermadec Islands region'},
#    'geometry': {'type': 'Point', 'coordinates': [-179.471, -30.9617, 275.27]},
#    'id': 'us6000h2hv'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.5,
#     'place': '42 km NNW of Te Anau, New Zealand',
#     'time': 1646544405365,
#     'updated': 1646607980781,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h2hj',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h2hj.geojson',
#     'felt': 2,
#     'cdi': 4.3,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 312,
#     'net': 'us',
#     'code': '6000h2hj',
#     'ids': ',us6000h2hj,',
#     'sources': ',us,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': None,
#     'dmin': 0.461,
#     'rms': 0.95,
#     'gap': 63,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.5 - 42 km NNW of Te Anau, New Zealand'},
#    'geometry': {'type': 'Point', 'coordinates': [167.4907, -45.0699, 86.26]},
#    'id': 'us6000h2hj'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.7,
#     'place': '111 km WSW of Akhiok, Alaska',
#     'time': 1646541751504,
#     'updated': 1646543821040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h2hg',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h2hg.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 112,
#     'net': 'us',
#     'code': '6000h2hg',
#     'ids': ',us6000h2hg,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 1.445,
#     'rms': 0.41,
#     'gap': 193,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.7 - 111 km WSW of Akhiok, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-155.8532, 56.5571, 35]},
#    'id': 'us6000h2hg'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.69,
#     'place': '1km ENE of The Geysers, CA',
#     'time': 1646540395990,
#     'updated': 1646602389139,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73701916',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc73701916.geojson',
#     'felt': 6,
#     'cdi': 2.9,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 113,
#     'net': 'nc',
#     'code': '73701916',
#     'ids': ',nc73701916,',
#     'sources': ',nc,',
#     'types': ',dyfi,focal-mechanism,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 81,
#     'dmin': 0.007306,
#     'rms': 0.06,
#     'gap': 35,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.7 - 1km ENE of The Geysers, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-122.745, 38.7798333, 0.47]},
#    'id': 'nc73701916'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.5,
#     'place': '49 km SE of Jiufen, Taiwan',
#     'time': 1646538716389,
#     'updated': 1646542505040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h2h5',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h2h5.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 312,
#     'net': 'us',
#     'code': '6000h2h5',
#     'ids': ',us6000h2h5,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 0.686,
#     'rms': 0.76,
#     'gap': 48,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.5 - 49 km SE of Jiufen, Taiwan'},
#    'geometry': {'type': 'Point', 'coordinates': [122.2398, 24.843, 110.98]},
#    'id': 'us6000h2h5'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.5,
#     'place': '1 km NE of San Juan Guichicovi, Mexico',
#     'time': 1646537361096,
#     'updated': 1646623986229,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h2h0',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h2h0.geojson',
#     'felt': 55,
#     'cdi': 5,
#     'mmi': 4.192,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 493,
#     'net': 'us',
#     'code': '6000h2h0',
#     'ids': ',us6000h2h0,',
#     'sources': ',us,',
#     'types': ',dyfi,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 2.906,
#     'rms': 1,
#     'gap': 115,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 5.5 - 1 km NE of San Juan Guichicovi, Mexico'},
#    'geometry': {'type': 'Point', 'coordinates': [-95.0836, 16.9706, 97.76]},
#    'id': 'us6000h2h0'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.9,
#     'place': '55 km S of Whites City, New Mexico',
#     'time': 1646537013576,
#     'updated': 1646537674127,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/tx2022enex',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/tx2022enex.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 129,
#     'net': 'tx',
#     'code': '2022enex',
#     'ids': ',us6000h2gz,tx2022enex,',
#     'sources': ',us,tx,',
#     'types': ',origin,phase-data,',
#     'nst': 16,
#     'dmin': 0.07461742324,
#     'rms': 0.3,
#     'gap': 55,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.9 - 55 km S of Whites City, New Mexico'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-104.4137638, 31.67672057, 6.979931641]},
#    'id': 'tx2022enex'},
#   {'type': 'Feature',
#    'properties': {'mag': 5,
#     'place': '196 km SW of Vaini, Tonga',
#     'time': 1646533997494,
#     'updated': 1646535086040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h2gu',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h2gu.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 385,
#     'net': 'us',
#     'code': '6000h2gu',
#     'ids': ',us6000h2gu,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 8.4,
#     'rms': 0.96,
#     'gap': 92,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 5.0 - 196 km SW of Vaini, Tonga'},
#    'geometry': {'type': 'Point', 'coordinates': [-176.3623, -22.5851, 10]},
#    'id': 'us6000h2gu'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.7,
#     'place': '203 km NNW of Santa Cruz da Graciosa, Portugal',
#     'time': 1646533573056,
#     'updated': 1646535594040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h2gv',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h2gv.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 340,
#     'net': 'us',
#     'code': '6000h2gv',
#     'ids': ',us6000h2gv,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 4.061,
#     'rms': 0.9,
#     'gap': 72,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.7 - 203 km NNW of Santa Cruz da Graciosa, Portugal'},
#    'geometry': {'type': 'Point', 'coordinates': [-29.1677, 40.6814, 10]},
#    'id': 'us6000h2gv'},
#   {'type': 'Feature',
#    'properties': {'mag': 4,
#     'place': '118 km N of Calama, Chile',
#     'time': 1646533552840,
#     'updated': 1646535947040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h2gt',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h2gt.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 246,
#     'net': 'us',
#     'code': '6000h2gt',
#     'ids': ',us6000h2gt,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 0.544,
#     'rms': 0.83,
#     'gap': 67,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.0 - 118 km N of Calama, Chile'},
#    'geometry': {'type': 'Point', 'coordinates': [-69.041, -21.3949, 119.47]},
#    'id': 'us6000h2gt'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.8,
#     'place': '39 km WNW of Skwentna, Alaska',
#     'time': 1646532158532,
#     'updated': 1646533170040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0222zj4xoz',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak0222zj4xoz.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 121,
#     'net': 'ak',
#     'code': '0222zj4xoz',
#     'ids': ',us6000h2gq,ak0222zj4xoz,',
#     'sources': ',us,ak,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.59,
#     'gap': None,
#     'magType': 'ml',
# ...
#     'gap': 168,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 3.0 - Rat Islands, Aleutian Islands, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [178.3331, 52.011, 12.64]},
#    'id': 'us6000h1ai'},
#   {'type': 'Feature',
#    'properties': {'mag': 4,
#     'place': '73 km WNW of Arauco, Chile',
#     'time': 1646106127309,
#     'updated': 1646259639040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h0zl',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h0zl.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 246,
#     'net': 'us',
#     'code': '6000h0zl',
#     'ids': ',us6000h0zl,',
#     'sources': ',us,',
#     'types': ',moment-tensor,origin,phase-data,',
#     'nst': None,
#     'dmin': 0.694,
#     'rms': 0.53,
#     'gap': 193,
#     'magType': 'mwr',
#     'type': 'earthquake',
#     'title': 'M 4.0 - 73 km WNW of Arauco, Chile'},
#    'geometry': {'type': 'Point', 'coordinates': [-74.0312, -36.9112, 10]},
#    'id': 'us6000h0zl'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.8,
#     'place': '124 km WNW of Naha, Japan',
#     'time': 1646104698872,
#     'updated': 1646199982040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h0zh',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h0zh.geojson',
#     'felt': 0,
#     'cdi': 1,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 354,
#     'net': 'us',
#     'code': '6000h0zh',
#     'ids': ',us6000h0zh,',
#     'sources': ',us,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': None,
#     'dmin': 1.482,
#     'rms': 0.57,
#     'gap': 62,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.8 - 124 km WNW of Naha, Japan'},
#    'geometry': {'type': 'Point', 'coordinates': [126.6138, 26.8027, 10]},
#    'id': 'us6000h0zh'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.1,
#     'place': '49 km N of Ambunti, Papua New Guinea',
#     'time': 1646100775665,
#     'updated': 1646199500040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h0z8',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h0z8.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 400,
#     'net': 'us',
#     'code': '6000h0z8',
#     'ids': ',us6000h0z8,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 10.522,
#     'rms': 0.91,
#     'gap': 114,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 5.1 - 49 km N of Ambunti, Papua New Guinea'},
#    'geometry': {'type': 'Point', 'coordinates': [142.755, -3.7724, 55.22]},
#    'id': 'us6000h0z8'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.5,
#     'place': '29 km NW of Stanley, Idaho',
#     'time': 1646099112160,
#     'updated': 1646198829040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h0z4',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h0z4.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 96,
#     'net': 'us',
#     'code': '6000h0z4',
#     'ids': ',mb80539349,us6000h0z4,',
#     'sources': ',mb,us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 0.835,
#     'rms': 0.82,
#     'gap': 59,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.5 - 29 km NW of Stanley, Idaho'},
#    'geometry': {'type': 'Point', 'coordinates': [-115.2041, 44.4058, 10]},
#    'id': 'us6000h0z4'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.7,
#     'place': '160 km S of Adak, Alaska',
#     'time': 1646095690458,
#     'updated': 1646460537040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h0y4',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h0y4.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 211,
#     'net': 'us',
#     'code': '6000h0y4',
#     'ids': ',us6000h0y4,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 1.403,
#     'rms': 0.91,
#     'gap': 217,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 3.7 - 160 km S of Adak, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-177.0558, 50.4522, 10]},
#    'id': 'us6000h0y4'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.9,
#     'place': '74 km SW of Nanwalek, Alaska',
#     'time': 1646094002938,
#     'updated': 1646094783957,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0222r8d3ze',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak0222r8d3ze.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 129,
#     'net': 'ak',
#     'code': '0222r8d3ze',
#     'ids': ',us6000h0xx,ak0222r8d3ze,',
#     'sources': ',us,ak,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.57,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.9 - 74 km SW of Nanwalek, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-152.8927, 58.9171, 57.6]},
#    'id': 'ak0222r8d3ze'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.52,
#     'place': 'Island of Hawaii, Hawaii',
#     'time': 1646092754420,
#     'updated': 1646099934210,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv72932967',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/hv72932967.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 98,
#     'net': 'hv',
#     'code': '72932967',
#     'ids': ',hv72932967,',
#     'sources': ',hv,',
#     'types': ',origin,phase-data,',
#     'nst': 25,
#     'dmin': None,
#     'rms': 0.12,
#     'gap': 126,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.5 - Island of Hawaii, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.482666666667, 19.1585, 31.11]},
#    'id': 'hv72932967'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.7,
#     'place': '171 km NE of Laikit, Laikit II (Dimembe), Indonesia',
#     'time': 1646090505775,
#     'updated': 1646460985040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h0x6',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h0x6.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 340,
#     'net': 'us',
#     'code': '6000h0x6',
#     'ids': ',us6000h0x6,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 2.012,
#     'rms': 0.81,
#     'gap': 73,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.7 - 171 km NE of Laikit, Laikit II (Dimembe), Indonesia'},
#    'geometry': {'type': 'Point', 'coordinates': [126.2063, 2.4275, 76.7]},
#    'id': 'us6000h0x6'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.3,
#     'place': '142 km SSE of Kuril’sk, Russia',
#     'time': 1646089830355,
#     'updated': 1646526590040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h23g',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h23g.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 284,
#     'net': 'us',
#     'code': '6000h23g',
#     'ids': ',us6000h23g,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 4.25,
#     'rms': 0.55,
#     'gap': 143,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.3 - 142 km SSE of Kuril’sk, Russia'},
#    'geometry': {'type': 'Point', 'coordinates': [148.4896, 44.0238, 10]},
#    'id': 'us6000h23g'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.1,
#     'place': '156 km E of Shikotan, Russia',
#     'time': 1646085870714,
#     'updated': 1646087662040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h0vy',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h0vy.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 400,
#     'net': 'us',
#     'code': '6000h0vy',
#     'ids': ',us6000h0vy,',
#     'sources': ',us,',
#     'types': ',moment-tensor,origin,phase-data,',
#     'nst': None,
#     'dmin': 4.385,
#     'rms': 0.85,
#     'gap': 137,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 5.1 - 156 km E of Shikotan, Russia'},
#    'geometry': {'type': 'Point', 'coordinates': [148.6636, 43.8866, 10]},
#    'id': 'us6000h0vy'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.1,
#     'place': 'Izu Islands, Japan region',
#     'time': 1646084911159,
#     'updated': 1646086579040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h0vr',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h0vr.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 259,
#     'net': 'us',
#     'code': '6000h0vr',
#     'ids': ',us6000h0vr,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 3.702,
#     'rms': 0.73,
#     'gap': 150,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.1 - Izu Islands, Japan region'},
#    'geometry': {'type': 'Point', 'coordinates': [138.683, 29.5303, 477.57]},
#    'id': 'us6000h0vr'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.4,
#     'place': 'Mariana Islands region',
#     'time': 1646080863122,
#     'updated': 1646673045040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h239',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h239.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 298,
#     'net': 'us',
#     'code': '6000h239',
#     'ids': ',us6000h239,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 4.87,
#     'rms': 0.93,
#     'gap': 106,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.4 - Mariana Islands region'},
#    'geometry': {'type': 'Point', 'coordinates': [147.7959, 17.5824, 10]},
#    'id': 'us6000h239'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.62,
#     'place': '7 km E of Pāhala, Hawaii',
#     'time': 1646080482840,
#     'updated': 1646672320040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv72932812',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/hv72932812.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 106,
#     'net': 'hv',
#     'code': '72932812',
#     'ids': ',us6000h0ux,hv72932812,',
#     'sources': ',us,hv,',
#     'types': ',origin,phase-data,',
#     'nst': 51,
#     'dmin': None,
#     'rms': 0.13,
#     'gap': 158,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.6 - 7 km E of Pāhala, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.411166666667, 19.1948333333333, 34.59]},
#    'id': 'hv72932812'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.4,
#     'place': '195 km SSW of Aykol, China',
#     'time': 1646078049752,
#     'updated': 1646672134040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h0up',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h0up.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 298,
#     'net': 'us',
#     'code': '6000h0up',
#     'ids': ',us6000h0up,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 2.675,
#     'rms': 1.12,
#     'gap': 84,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.4 - 195 km SSW of Aykol, China'},
#    'geometry': {'type': 'Point', 'coordinates': [79.3194, 39.3126, 10]},
#    'id': 'us6000h0up'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.2,
#     'place': '101 km NE of Tobelo, Indonesia',
#     'time': 1646076738692,
#     'updated': 1646671820040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h0um',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h0um.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 271,
#     'net': 'us',
#     'code': '6000h0um',
#     'ids': ',us6000h0um,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 2.055,
#     'rms': 0.83,
#     'gap': 76,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.2 - 101 km NE of Tobelo, Indonesia'},
#    'geometry': {'type': 'Point', 'coordinates': [128.5826, 2.44, 228.52]},
#    'id': 'us6000h0um'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.7,
#     'place': 'Utah',
#     'time': 1646075603560,
#     'updated': 1646671602040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/uu60483507',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/uu60483507.geojson',
#     'felt': 5,
#     'cdi': 3.1,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 114,
#     'net': 'uu',
#     'code': '60483507',
#     'ids': ',us6000h0ui,uu60483507,',
#     'sources': ',us,uu,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': 18,
#     'dmin': 0.07837,
#     'rms': 0.19,
#     'gap': 47,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.7 - Utah'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-112.2096667, 38.5821667, -2.92]},
#    'id': 'uu60483507'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.5,
#     'place': '101 km SE of Nikolski, Alaska',
#     'time': 1646074834984,
#     'updated': 1646669403040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h0uu',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h0uu.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 188,
#     'net': 'us',
#     'code': '6000h0uu',
#     'ids': ',ak0222pw0tfm,us6000h0uu,',
#     'sources': ',ak,us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 0.934,
#     'rms': 0.73,
#     'gap': 235,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 3.5 - 101 km SE of Nikolski, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-167.6609, 52.3864, 10]},
#    'id': 'us6000h0uu'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.3,
#     'place': '271 km ESE of Levuka, Fiji',
#     'time': 1646070772225,
#     'updated': 1646668779040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h237',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h237.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 284,
#     'net': 'us',
#     'code': '6000h237',
#     'ids': ',us6000h237,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 3.683,
#     'rms': 0.79,
#     'gap': 131,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.3 - 271 km ESE of Levuka, Fiji'},
#    'geometry': {'type': 'Point', 'coordinates': [-178.2804, -18.9497, 583.93]},
#    'id': 'us6000h237'}],
#  'bbox': [-179.9245, -58.7354, -2.92, 178.35633333333, 85.3733, 583.93]}

# %% [markdown]
# Since JSON is just a dictionary, we can access subsets of the data can with square brackets, using labels for the named elements in a key-value pair, and numerals for positional indexing of list items.
#
# Hint: whenever you see a file that ends in `.geojson`, you'll probably want to extract the data thats stored in the `features` dictionary:

# %%
quakes = data['features']
quakes[0]
# Out:
# {'type': 'Feature',
#  'properties': {'mag': 4.9,
#   'place': '243 km W of Tual, Indonesia',
#   'time': 1646673829778,
#   'updated': 1646674893040,
#   'tz': None,
#   'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h2sf',
#   'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h2sf.geojson',
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'alert': None,
#   'status': 'reviewed',
#   'tsunami': 0,
#   'sig': 369,
#   'net': 'us',
#   'code': '6000h2sf',
#   'ids': ',us6000h2sf,',
#   'sources': ',us,',
#   'types': ',origin,phase-data,',
#   'nst': None,
#   'dmin': 2.158,
#   'rms': 0.76,
#   'gap': 47,
#   'magType': 'mb',
#   'type': 'earthquake',
#   'title': 'M 4.9 - 243 km W of Tual, Indonesia'},
#  'geometry': {'type': 'Point', 'coordinates': [130.5771, -5.9336, 132.38]},
#  'id': 'us6000h2sf'}

# %% [markdown]
# Because it is a nested dictionary at this point, we can use indexing into the dictionary to extract results.  Recall our earlier use of nested dictionaries? This is why we learned how to navigate nested dictionaries:

# %%
for q in quakes:
    print(q['properties']['title'])
# Out:
# M 4.9 - 243 km W of Tual, Indonesia
# M 4.8 - 58 km NNE of Nanao, Japan
# M 2.7 - 35 km SSW of Los Ybanez, Texas
# M 3.3 - 66 km N of Charlotte Amalie, U.S. Virgin Islands
# M 3.5 - 6km WNW of Bodie, CA
# M 2.5 - 11 km ENE of Pāhala, Hawaii
# M 4.8 - 106 km WSW of Wuwei, China
# M 2.5 - 5 km S of Pāhala, Hawaii
# M 3.0 - 10 km SSE of Gardendale, Texas
# M 2.7 - 9 km SSE of Maria Antonia, Puerto Rico
# M 4.9 - 99 km S of Kushiro, Japan
# M 3.4 - 4 km SSE of Pāhala, Hawaii
# M 2.7 - 1 km SE of Indios, Puerto Rico
# M 4.4 - 29 km NNW of Labuan Lombok, Indonesia
# M 3.3 - 4 km WSW of Pāhala, Hawaii
# M 6.1 - Fiji region
# M 3.2 - 35 km WSW of Pole Ojea, Puerto Rico
# M 3.0 - 55 km S of Whites City, New Mexico
# M 2.5 - 3 km SW of Indios, Puerto Rico
# M 2.8 - 180 km W of Ferndale, California
# M 2.6 - 49 km N of Punta Cana, Dominican Republic
# M 3.1 - 150 km W of Haines Junction, Canada
# M 5.0 - Mid-Indian Ridge
# M 4.2 - 30 km WSW of Orcopampa, Peru
# M 4.4 - 21 km SW of Pogradec, Albania
# M 4.4 - 96 km ESE of Ishinomaki, Japan
# M 4.4 - 38 km SW of Turt, Mongolia
# M 2.7 - 56 km S of Whites City, New Mexico
# M 4.8 - 229 km N of Inuvik, Canada
# M 4.2 - Philippine Islands region
# M 4.2 - 36 km ESE of Farkhār, Afghanistan
# M 3.0 - Fox Islands, Aleutian Islands, Alaska
# M 6.0 - South Sandwich Islands region
# M 4.1 - 99 km W of San Antonio de los Cobres, Argentina
# M 4.1 - 129 km E of San Pedro de Atacama, Chile
# M 2.6 - 51 km E of Pedro Bay, Alaska
# M 4.2 - 140 km N of Cruz Bay, U.S. Virgin Islands
# M 4.0 - 24 km WNW of Pucara, Peru
# M 4.4 - 77 km NNE of Ruteng, Indonesia
# M 3.9 - 21 km NNE of Skwentna, Alaska
# M 2.7 - 3 km S of Pāhala, Hawaii
# M 5.5 - 64 km WNW of Vinchina, Argentina
# M 4.6 - Lake Edward region, Uganda
# M 5.1 - Kermadec Islands region
# M 4.5 - 42 km NNW of Te Anau, New Zealand
# M 2.7 - 111 km WSW of Akhiok, Alaska
# M 2.7 - 1km ENE of The Geysers, CA
# M 4.5 - 49 km SE of Jiufen, Taiwan
# M 5.5 - 1 km NE of San Juan Guichicovi, Mexico
# M 2.9 - 55 km S of Whites City, New Mexico
# M 5.0 - 196 km SW of Vaini, Tonga
# M 4.7 - 203 km NNW of Santa Cruz da Graciosa, Portugal
# M 4.0 - 118 km N of Calama, Chile
# M 2.8 - 39 km WNW of Skwentna, Alaska
# M 5.1 - 73 km ESE of Naze, Japan
# M 4.8 - 211 km SSE of Sarangani, Philippines
# M 3.0 - 178 km SSW of Akhiok, Alaska
# M 5.0 - 124 km ESE of ‘Ohonua, Tonga
# M 3.8 - 2 km S of Mount Barker, Australia
# M 4.5 - 114 km SSW of Hihifo, Tonga
# M 4.5 - 36 km NNE of Yigo Village, Guam
# M 3.4 - Rat Islands, Aleutian Islands, Alaska
# M 4.2 - 115 km W of Abra Pampa, Argentina
# M 3.7 - 126 km NNE of Suárez, Puerto Rico
# M 2.9 - 11 km WNW of Stanley, Idaho
# M 2.6 - 13 km WNW of Stanley, Idaho
# M 4.8 - 69 km NNW of Ternate, Indonesia
# M 3.2 - 2km E of Pinnacles, CA
# M 4.1 - 76 km NNW of Charlotte Amalie, U.S. Virgin Islands
# M 4.5 - 82 km NNW of Phôngsali, Laos
# M 5.1 - 9 km E of Parapat, Indonesia
# M 5.5 - 102 km SSW of Banda Aceh, Indonesia
# M 3.3 - 13km SE of Bodfish, CA
# M 2.5 - 12km N of New Idria, CA
# M 4.4 - 263 km E of Levuka, Fiji
# M 2.7 - 3 km W of Pāhala, Hawaii
# M 2.6 - 2 km NW of Indios, Puerto Rico
# M 5.1 - 68 km NNE of Puerto Ocopa, Peru
# M 2.9 - 9 km N of Cantwell, Alaska
# M 5.0 - South Sandwich Islands region
# M 3.3 - 57 km S of Whites City, New Mexico
# M 4.3 - south of the Fiji Islands
# M 4.8 - Southwest Indian Ridge
# M 4.3 - 57 km S of Whites City, New Mexico
# M 5.7 - 47 km NW of Abra Pampa, Argentina
# M 3.6 - 80 km NW of Yakutat, Alaska
# M 4.4 - 21 km E of Kirovsk, Russia
# M 4.7 - 278 km WSW of Tual, Indonesia
# M 2.6 - 4 km SW of Pāhala, Hawaii
# M 5.1 - 152 km E of Miyako, Japan
# M 4.4 - 17 km W of San Nicolò, Italy
# M 4.7 - 135 km E of Miyako, Japan
# M 2.8 - 27 km SW of Atka, Alaska
# M 4.3 - 121 km NW of Pante Makasar, Timor Leste
# M 4.4 - 39 km WSW of Fārsān, Iran
# M 5.0 - South Sandwich Islands region
# M 2.8 - 24 km NE of Chase, Alaska
# M 4.9 - 206 km NE of Lospalos, Timor Leste
# M 3.7 - 87 km N of Charlotte Amalie, U.S. Virgin Islands
# M 2.5 - 3 km SW of Guánica, Puerto Rico
# M 4.3 - 111 km SSW of Labuan, Indonesia
# M 2.8 - Rat Islands, Aleutian Islands, Alaska
# M 4.4 - 55 km SE of Mohr, Iran
# M 2.9 - 53 km N of Hiko, Nevada
# M 3.1 - 33 km NNE of Atka, Alaska
# M 3.1 - 4 km S of Pāhala, Hawaii
# M 4.3 - 64 km N of Manado, Indonesia
# M 3.1 - 37 km NNW of Toyah, Texas
# M 4.4 - 60 km NW of Coquimbo, Chile
# M 5.4 - 70 km ENE of Kimbe, Papua New Guinea
# M 4.6 - 271 km S of Sinabang, Indonesia
# M 4.3 - 86 km SSW of Komodo, Indonesia
# M 4.2 - 287 km NE of Lospalos, Timor Leste
# M 4.3 - 67 km W of Nuquí, Colombia
# M 4.2 - Rat Islands, Aleutian Islands, Alaska
# M 5.0 - Kermadec Islands region
# M 2.6 - 8 km SE of Pole Ojea, Puerto Rico
# M 2.5 - 2 km ESE of Magas Arriba, Puerto Rico
# M 4.6 - western Xizang
# M 2.9 - 6 km E of Pāhala, Hawaii
# M 5.0 - Kermadec Islands region
# M 5.1 - Kermadec Islands region
# M 2.5 - 4 km WSW of La Parguera, Puerto Rico
# M 3.1 - 54 km N of Hiko, Nevada
# M 4.0 - 6 km SSW of Salvaleón de Higüey, Dominican Republic
# M 3.3 - 46 km N of Arecibo, Puerto Rico
# M 3.7 - 22 km W of Klerksdorp, South Africa
# M 2.8 - 20km SSE of Estacion Coahuila, B.C., MX
# M 4.3 - 52 km SE of Kongolo, Democratic Republic of the Congo
# M 5.1 - 23 km NE of Pujocucho, Peru
# M 4.3 - 33 km S of La Gomera, Guatemala
# M 4.3 - 128 km ESE of Iquique, Chile
# M 2.5 - Rat Islands, Aleutian Islands, Alaska
# M 2.7 - 8 km E of Pāhala, Hawaii
# M 4.2 - Fiji region
# M 5.1 - Chagos Archipelago region
# M 2.7 - 9 km S of Volcano, Hawaii
# M 2.7 - 71 km NNE of San Juan, Puerto Rico
# M 2.6 - 25 km WNW of Stanley, Idaho
# M 4.7 - Izu Islands, Japan region
# M 3.3 - 79 km SE of Nikolski, Alaska
# M 5.7 - Veracruz, Mexico
# M 4.9 - 79 km SE of Farkhār, Afghanistan
# M 5.1 - Kermadec Islands, New Zealand
# M 2.7 - 13 km SSW of La Parguera, Puerto Rico
# M 4.9 - Kermadec Islands region
# M 3.8 - 83 km N of Cruz Bay, U.S. Virgin Islands
# M 3.8 - 0km NNW of The Geysers, CA
# M 4.9 - 55 km SW of Jiquilillo, Nicaragua
# M 2.6 - 1 km ESE of Magas Arriba, Puerto Rico
# M 4.8 - 33 km NNE of Fiambalá, Argentina
# M 4.3 - 165 km NNE of Shi Yomi, India
# M 3.0 - Rat Islands, Aleutian Islands, Alaska
# M 3.5 - Rat Islands, Aleutian Islands, Alaska
# M 2.7 - 178 km W of Crescent City, California
# M 4.3 - 2 km NNE of San Nicolas, Philippines
# M 5.0 - 58 km N of Narganá, Panama
# M 3.2 - 20 km NW of San Antonio, Puerto Rico
# M 4.0 - 120 km N of Charlotte Amalie, U.S. Virgin Islands
# M 4.5 - 57 km NW of Bukittinggi, Indonesia
# M 2.5 - 34 km NW of Stanley, Idaho
# M 4.6 - 11 km ESE of Villa Presidente Frei, Ñuñoa, Santiago, Chile, Chile
# M 4.4 - Banda Sea
# M 4.3 - 73 km N of Güiria, Venezuela
# M 4.6 - 125 km WNW of Naha, Japan
# M 4.7 - 127 km ENE of Petropavlovsk-Kamchatsky, Russia
# M 4.6 - 86 km SE of Gorontalo, Indonesia
# M 3.8 - 105 km N of Cruz Bay, U.S. Virgin Islands
# M 2.8 - 32 km SE of Malaga, New Mexico
# M 4.3 - off the coast of Michoacan, Mexico
# M 5.0 - West Chile Rise
# M 4.6 - 147 km NW of Nuku‘alofa, Tonga
# M 5.0 - 37 km NE of Sorong, Indonesia
# M 4.9 - 182 km SW of Lorengau, Papua New Guinea
# M 2.7 - 20km NW of Desert Center, CA
# M 5.5 - 63 km S of Kokopo, Papua New Guinea
# M 3.0 - 33 km WNW of Kalaoa, Hawaii
# M 4.8 - West Chile Rise
# M 3.2 - 4 km SW of Pāhala, Hawaii
# M 5.4 - north of Ascension Island
# M 3.0 - 4 km N of Animas, Puerto Rico
# M 3.1 - 11 km SW of Vardane, Russia
# M 4.5 - 47 km S of Nabire, Indonesia
# M 2.8 - 8km NNE of Walker, CA
# M 5.1 - Kermadec Islands, New Zealand
# M 4.9 - 139 km S of Severo-Kuril’sk, Russia
# M 3.3 - 1 km ESE of Guaynabo, Puerto Rico
# M 5.5 - Kermadec Islands, New Zealand
# M 2.5 - 1 km SSE of Indios, Puerto Rico
# M 2.7 - 2 km SSW of Liborio Negron Torres, Puerto Rico
# M 2.6 - 35 km S of False Pass, Alaska
# M 6.6 - Kermadec Islands, New Zealand
# M 2.7 - 30 km SSW of Chalkyitsik, Alaska
# M 3.2 - 53 km N of Tierras Nuevas Poniente, Puerto Rico
# M 5.0 - South Sandwich Islands region
# M 3.8 - 34 km WNW of Tatitlek, Alaska
# M 5.0 - 52 km NE of Neiafu, Tonga
# M 3.5 - 65 km N of Arecibo, Puerto Rico
# M 5.2 - 37 km NE of Bāzārak, Afghanistan
# M 4.1 - 72 km N of Arecibo, Puerto Rico
# M 3.4 - 4 km S of Joseph, Utah
# M 4.5 - Banda Sea
# M 5.0 - southeast of the Loyalty Islands
# M 4.9 - 194 km WSW of Abepura, Indonesia
# M 4.3 - Tarapaca, Chile
# M 2.5 - 18 km WNW of Volcano, Hawaii
# M 5.4 - central Mid-Atlantic Ridge
# M 4.7 - 45 km SSW of Paracas, Peru
# M 4.8 - 152 km E of Shikotan, Russia
# M 4.5 - 155 km E of Shikotan, Russia
# M 4.6 - 118 km SW of Bam, Iran
# M 3.4 - 91km SSW of Alberto Oviedo Mota, B.C., MX
# M 2.8 - Rat Islands, Aleutian Islands, Alaska
# M 3.5 - 153 km N of Charlotte Amalie, U.S. Virgin Islands
# M 4.4 - 144 km SSE of Kuril’sk, Russia
# M 4.6 - 148 km E of Shikotan, Russia
# M 2.7 - 31 km WNW of Valdez, Alaska
# M 4.8 - Southern Qinghai, China
# M 5.0 - 128 km SSW of Merizo Village, Guam
# M 4.3 - 172 km ESE of Shikotan, Russia
# M 3.4 - 75 km NNW of San Antonio, Puerto Rico
# M 5.2 - 83 km SE of Attu Station, Alaska
# M 5.3 - 3 km S of San Francisco Logueche, Mexico
# M 3.5 - 28 km SSE of Mina, Nevada
# M 4.4 - northern East Pacific Rise
# M 4.2 - north of Severnaya Zemlya
# M 2.7 - 5km SSW of Lexington Hills, CA
# M 2.6 - 12 km SSW of Chignik, Alaska
# M 2.5 - 8km WSW of Petrolia, CA
# M 4.5 - 112 km W of Pariaman, Indonesia
# M 4.9 - 126 km SSW of Singaparna, Indonesia
# M 4.3 - 7 km NNE of Jordán, Colombia
# M 4.7 - south of the Kermadec Islands
# M 4.3 - 116 km NNW of Davila, Philippines
# M 2.6 - northern Alaska
# M 2.8 - 13 km S of Guánica, Puerto Rico
# M 4.5 - 71 km SE of Gorontalo, Indonesia
# M 2.8 - 6 km W of Fuig, Puerto Rico
# M 5.4 - Kermadec Islands, New Zealand
# M 5.1 - 23 km SW of Meulaboh, Indonesia
# M 4.2 - 7 km WNW of Mamrux, Azerbaijan
# M 2.7 - Rat Islands, Aleutian Islands, Alaska
# M 2.7 - 55 km S of Whites City, New Mexico
# M 2.6 - 21 km S of Tallaboa, Puerto Rico
# M 4.4 - south of the Fiji Islands
# M 2.5 - 1 km SW of La Parguera, Puerto Rico
# M 4.4 - 201 km ENE of Levuka, Fiji
# M 2.7 - 2 km SSW of Lluveras, Puerto Rico
# M 3.8 - 124 km NE of Cruz Bay, U.S. Virgin Islands
# M 3.9 - 14 km WSW of San Rafael del Yuma, Dominican Republic
# M 2.6 - 9 km SSE of Guánica, Puerto Rico
# M 2.5 - 12 km W of Kalifornsky, Alaska
# M 2.6 - 5km WSW of Ojai, CA
# M 3.1 - 11 km SSW of Weston, Colorado
# M 5.8 - Kermadec Islands region
# M 4.8 - Kermadec Islands region
# M 5.3 - Kermadec Islands region
# M 2.6 - 6 km ENE of La Parguera, Puerto Rico
# M 2.8 - 5km W of Ojai, CA
# M 2.8 - 5km WSW of Ojai, CA
# M 2.7 - 4 km SW of Pāhala, Hawaii
# M 5.3 - 84 km E of ‘Ohonua, Tonga
# M 3.5 - 27 km SE of Boca de Yuma, Dominican Republic
# M 4.5 - 263 km WSW of Tual, Indonesia
# M 3.9 - 275 km SE of Chiniak, Alaska
# M 2.5 - 5km WSW of Ojai, CA
# M 4.4 - 139 km E of Shikotan, Russia
# M 3.0 - Rat Islands, Aleutian Islands, Alaska
# M 4.0 - 73 km WNW of Arauco, Chile
# M 4.8 - 124 km WNW of Naha, Japan
# M 5.1 - 49 km N of Ambunti, Papua New Guinea
# M 2.5 - 29 km NW of Stanley, Idaho
# M 3.7 - 160 km S of Adak, Alaska
# M 2.9 - 74 km SW of Nanwalek, Alaska
# M 2.5 - Island of Hawaii, Hawaii
# M 4.7 - 171 km NE of Laikit, Laikit II (Dimembe), Indonesia
# M 4.3 - 142 km SSE of Kuril’sk, Russia
# M 5.1 - 156 km E of Shikotan, Russia
# M 4.1 - Izu Islands, Japan region
# M 4.4 - Mariana Islands region
# M 2.6 - 7 km E of Pāhala, Hawaii
# M 4.4 - 195 km SSW of Aykol, China
# M 4.2 - 101 km NE of Tobelo, Indonesia
# M 2.7 - Utah
# M 3.5 - 101 km SE of Nikolski, Alaska
# M 4.3 - 271 km ESE of Levuka, Fiji

# %% [markdown]
# **SIDE BAR: GeoJSON?**
#
# Working with geospatial data over the web, you will inevitably encounter called GeoJSON. GeoJSON is just JSON (which is just...???) with a slightly more well-defined schema to distinguish between metadata, spatial features, and classes of spatial features (e.g. points vs. lines vs. polygons).
#
# There's lots of great tools out there for working with GeoJSON, but chief among them is [geojson.io](https://geojson.io). Try copying the first 5 entries from the quakes list into the `features` list on geojson.io and see what you find.
#
# HINT: it's a little bit tricker to go from Python to JSON than from JSON to Python because Python doesn't care about single-quotes vs. double quotes, but JavaScript does. You can use the `json.dumps()` method to convert a Python dictionary to a valid JSON string.

# %%
print(json.dumps(response.json()['features'][:5]))
# Out:
# [{"type": "Feature", "properties": {"mag": 4.9, "place": "243 km W of Tual, Indonesia", "time": 1646673829778, "updated": 1646674893040, "tz": null, "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us6000h2sf", "detail": "https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h2sf.geojson", "felt": null, "cdi": null, "mmi": null, "alert": null, "status": "reviewed", "tsunami": 0, "sig": 369, "net": "us", "code": "6000h2sf", "ids": ",us6000h2sf,", "sources": ",us,", "types": ",origin,phase-data,", "nst": null, "dmin": 2.158, "rms": 0.76, "gap": 47, "magType": "mb", "type": "earthquake", "title": "M 4.9 - 243 km W of Tual, Indonesia"}, "geometry": {"type": "Point", "coordinates": [130.5771, -5.9336, 132.38]}, "id": "us6000h2sf"}, {"type": "Feature", "properties": {"mag": 4.8, "place": "58 km NNE of Nanao, Japan", "time": 1646672328869, "updated": 1646674777040, "tz": null, "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us6000h2s5", "detail": "https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h2s5.geojson", "felt": null, "cdi": null, "mmi": null, "alert": null, "status": "reviewed", "tsunami": 0, "sig": 354, "net": "us", "code": "6000h2s5", "ids": ",us6000h2s5,", "sources": ",us,", "types": ",origin,phase-data,", "nst": null, "dmin": 1.224, "rms": 0.6, "gap": 88, "magType": "mww", "type": "earthquake", "title": "M 4.8 - 58 km NNE of Nanao, Japan"}, "geometry": {"type": "Point", "coordinates": [137.2733, 37.5197, 4.76]}, "id": "us6000h2s5"}, {"type": "Feature", "properties": {"mag": 2.7, "place": "35 km SSW of Los Ybanez, Texas", "time": 1646672217284, "updated": 1646674649040, "tz": null, "url": "https://earthquake.usgs.gov/earthquakes/eventpage/tx2022eqbg", "detail": "https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/tx2022eqbg.geojson", "felt": null, "cdi": null, "mmi": null, "alert": null, "status": "reviewed", "tsunami": 0, "sig": 112, "net": "tx", "code": "2022eqbg", "ids": ",us6000h2s1,tx2022eqbg,", "sources": ",us,tx,", "types": ",origin,phase-data,", "nst": 10, "dmin": 0.2355105413, "rms": 0.1, "gap": 68, "magType": "ml", "type": "earthquake", "title": "M 2.7 - 35 km SSW of Los Ybanez, Texas"}, "geometry": {"type": "Point", "coordinates": [-102.0785299, 32.42706299, 7.60542806]}, "id": "tx2022eqbg"}, {"type": "Feature", "properties": {"mag": 3.34, "place": "66 km N of Charlotte Amalie, U.S. Virgin Islands", "time": 1646672076600, "updated": 1646674506040, "tz": null, "url": "https://earthquake.usgs.gov/earthquakes/eventpage/pr71339393", "detail": "https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr71339393.geojson", "felt": null, "cdi": null, "mmi": null, "alert": null, "status": "reviewed", "tsunami": 0, "sig": 172, "net": "pr", "code": "71339393", "ids": ",us6000h2sc,pr71339393,", "sources": ",us,pr,", "types": ",origin,phase-data,", "nst": 6, "dmin": null, "rms": 0.24, "gap": 318, "magType": "md", "type": "earthquake", "title": "M 3.3 - 66 km N of Charlotte Amalie, U.S. Virgin Islands"}, "geometry": {"type": "Point", "coordinates": [-65.0133333333333, 18.9413333333333, 15.96]}, "id": "pr71339393"}, {"type": "Feature", "properties": {"mag": 3.54, "place": "6km WNW of Bodie, CA", "time": 1646670162910, "updated": 1646675219746, "tz": null, "url": "https://earthquake.usgs.gov/earthquakes/eventpage/nc73702486", "detail": "https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc73702486.geojson", "felt": 11, "cdi": 3.4, "mmi": 3.308, "alert": null, "status": "reviewed", "tsunami": 0, "sig": 197, "net": "nc", "code": "73702486", "ids": ",nc73702486,us6000h2rw,nn00835007,", "sources": ",nc,us,nn,", "types": ",dyfi,focal-mechanism,moment-tensor,nearby-cities,origin,phase-data,scitech-link,shakemap,", "nst": 50, "dmin": 0.3079, "rms": 0.18, "gap": 94, "magType": "mw", "type": "earthquake", "title": "M 3.5 - 6km WNW of Bodie, CA"}, "geometry": {"type": "Point", "coordinates": [-119.0830002, 38.2228317, 13.85]}, "id": "nc73702486"}]

# %% [markdown]
# Extracting data from nested dictionaries might be a good job for **list comprehension**:

# %%
for q in quakes:
    break

# %%
d = {
    'magnitude': [q['properties']['mag'] for q in quakes],
    'depth': [q['geometry']['coordinates'][2] for q in quakes]
}
df = pd.DataFrame.from_dict(d)

df.head()
# Out:
#    magnitude       depth
# 0       4.90  132.380000
# 1       4.80    4.760000
# 2       2.70    7.605428
# 3       3.34   15.960000
# 4       3.54   13.850000

# %%
print(df.describe())
# Out:
#         magnitude       depth
# count  286.000000  286.000000
# mean     3.926888   56.980374
# std      0.971373   96.597982
# min      2.450000   -2.920000
# 25%      2.900000   10.000000
# 50%      4.200000   13.760000
# 75%      4.700000   65.450000
# max      6.600000  583.930000

# %%
df.plot(x='magnitude', y='depth', kind='scatter')
# Out:
# <AxesSubplot:xlabel='magnitude', ylabel='depth'>

# %% [markdown]
# # 3. Geocoding
#
# Now on to the main course: geocoding APIs.

# %% [markdown]
# ## 3.1. What is geocoding?

# %% [markdown]
# **Geocoding** describes the process of converting place names and addresses to geographic coordinates (e.g. lat/lon).

# %% [markdown]
# <center><img src="https://dmpublisher.s3-us-west-2.amazonaws.com/old-dm/directionsmag.com/ee/images/newsletter/2004/10_20/EDramowicz_Figure1_lg.gif"></center>

# %% [markdown]
# Reverse geocoding is just the opposite process: using geographic coordinates to extract meaningful place names/addresses.

# %% [markdown]
# Perhaps this sounds like a dull topic, but **geocoding is a fundamental tool for anyone wishing to do spatial data analysis**.
#
# Why?

# %% [markdown]
# - 9 times out of 10, your data will have _either_ geographic coordinates _or_ administrative boundary names, but not both!
# - 9 times out of 10 you will want to use additional data sources for which the above statement also applies
# - Geocoding allows you to translate between the two (e.g. merging Census data into Craiglist rental listings)

# %% [markdown]
# ## 3.2 Geocoding with the Mapbox API

# %% [markdown]
# Services like Google Maps and Mapbox have various APIs that let you access its services through code instead of through GUI apps. This one from Mapbox lets you look up the latitude-longitude coordinates of street addresses. You'll need to create a Mapbox API token in order to use this API, which you can do by following the instructions [here ](https://www.mapbox.com/signin/?route-to=%22/account/access-tokens%22) if you have not alread done so.

# %% [markdown]
# The Mapbox API queries work just like the ones we've already seen, but now we're including our own query parameters in the URL endpoint!
#
# **API documentation:**
# https://www.mapbox.com/api-documentation/#geocoding
#
# **API endpoint:**
# https://api.mapbox.com/geocoding/v5/mapbox.places
#
# **API endpoint with query parameters:**
# https://api.mapbox.com/geocoding/v5/mapbox.places/Wurster+Hall.json?access_token=pk.eyJ1IjoiY3AyNTVkZW1vIiwiYSI6ImRPcTlnTUEifQ.3C0d0Nk_rcwV-8JF29PU-w

# %% [markdown]
# ### 3.2.1. A word about API keys, tokens, and passwords in general
#
# It's never a good idea to print an API key in a public document, including a script or notebook like this one. Particularly when you're using Git, deleting private data after you've already committed the change won't remove the data from your project history!
#
# Instead, its good practice to create a small .json file which you can read into Python without ever having to print its contents. In this case, let's use a text editor to create a file named **mapbox_api_key.json** and put it in the `data/` directory. It's contents should look like this:
#
# ```javascript
# {"key": "<your API key here>"}
# ```
#
# Now we can read the API key from disk:

# %%
import json

with open("data/mapbox_api_key.json", 'r') as f:
    key_file = f.read()
    
my_api_key = json.loads(key_file)['key']

# %% [markdown]
# ### 3.2.2. Constructing an API query
# Now we're ready to format our API request.

# %%
import requests

base_url = 'https://api.mapbox.com/geocoding/v5/mapbox.places/'
address = 'Wurster Hall'
params = {
    'limit': 1,  # just get the first record
    'access_token': my_api_key}

url = requests.Request('GET', base_url + address + '.json', params=params).prepare().url

# %% [markdown]
# This looks a little more complicated than what we saw last class. The main reason for this is that we are now doing more than simply submitting a `GET` request to URL whose full endpoint we know in advance. Instead, we just know the base URL of our API, and are using strings and key-value pairs to format the rest of the endpoint. This is pretty straightforward with one exception: HTTP doesn't know how to handle white space `" "` and many other special characters. So we are relying on the `Request.prepare()` method to take our input data and format it into a string that can be understood by HTTP.
#
# You can try printing the url in the cell below to see what this formatted version of the URL looks like, but be careful because it will contain your API key!

# %%
print(url)

# %% [markdown]
# ### 3.2.3. Making the request and parsing the response

# %%
data['features'][0]['center']
# Out:
# [-122.254883, 37.870818]

# %%
from pprint import PrettyPrinter as pp
response = requests.get(url)
results = response.text
data = json.loads(results)
data
# Out:
# {'type': 'FeatureCollection',
#  'query': ['wurster', 'hall'],
#  'features': [{'id': 'poi.472446416066',
#    'type': 'Feature',
#    'place_type': ['poi'],
#    'relevance': 1,
#    'properties': {'foursquare': '4b56554cf964a520ce0b28e3',
#     'landmark': True,
#     'address': '230 Wurster Hall #1820',
#     'category': 'college art building, building'},
#    'text': 'Wurster Hall / College of Environmental Design',
#    'place_name': 'Wurster Hall / College of Environmental Design, 230 Wurster Hall #1820, Berkeley, California 94704, United States',
#    'center': [-122.254883, 37.870818],
#    'geometry': {'coordinates': [-122.254883, 37.870818], 'type': 'Point'},
#    'context': [{'id': 'neighborhood.12468009734905880',
#      'text': 'University of California'},
#     {'id': 'postcode.13849498828668840', 'text': '94704'},
#     {'id': 'place.9820619379990170',
#      'wikidata': 'Q484678',
#      'text': 'Berkeley'},
#     {'id': 'district.11187960009291250',
#      'wikidata': 'Q107146',
#      'text': 'Alameda County'},
#     {'id': 'region.9803118085738010',
#      'short_code': 'US-CA',
#      'wikidata': 'Q99',
#      'text': 'California'},
#     {'id': 'country.19678805456372290',
#      'wikidata': 'Q30',
#      'short_code': 'us',
#      'text': 'United States'}]}],
#  'attribution': 'NOTICE: © 2022 Mapbox and its suppliers. All rights reserved. Use of this data is subject to the Mapbox Terms of Service (https://www.mapbox.com/about/maps/). This response and the information it contains may not be retained. POI(s) provided by Foursquare.'}

# %% [markdown]
# Does anyone think they have what it takes to extract the coordinates from our API response data?

# %% [markdown]
# ### 3.2.5 Exercises
#
# 1. Search for some other addresses or landmarks!
# 2. Try storing your code as a function named `get_coords()` so that you need only supply a place name and your function will return the coordinates as list or tuple:
#    ```python
#     def get_coords(place_str):
#
#         # do something with "place_str"
#
#         return coords
#
#    ```
# 2. Take a look at the [API documentation](https://www.mapbox.com/api-documentation/#geocoding). Can you figure out how to retrieve other points of interest near Wurster Hall?

# %%
# %%html
# <iframe style="border-radius:12px" src="https://open.spotify.com/embed/track/2KnJ183quw14FCd3Lb3pqL?utm_source=generator" width="30%" height="80" frameBorder="0" allowfullscreen="" allow="autoplay; clipboard-write; encrypted-media; fullscreen; picture-in-picture"></iframe>
# Out:
# <iframe style="border-radius:12px" src="https://open.spotify.com/embed/track/2KnJ183quw14FCd3Lb3pqL?utm_source=generator" width="30%" height="80" frameBorder="0" allowfullscreen="" allow="autoplay; clipboard-write; encrypted-media; fullscreen; picture-in-picture"></iframe>

# %% [markdown]
# ### 3.2.4. The Mapbox SDK

# %% [markdown]
# Mapbox also maintans its own Python package which makes it a little easier to execute HTTP requests against its API. You can find the documentation [here](https://mapbox-mapbox.readthedocs-hosted.com/en/latest/index.html)
#
# NOTE: the Mapbox Python API seems to be a bit buggy. In particular it doesn't seem to support Python > 3.9. If you encounter any issues trying to import modules from this library, the best thing to do is to roll back your Python version. From a terminal, you can do:
#
# ```bash
# conda install python=3.9
# ```
#
# and then restart your notebook kernel using the Kernel drop down menu in the menu panel above (or by typing `00` in rapid succession in command mode).

# %% [markdown]
# #### 3.2.4.1. Forward Geocoding
#
# Forward geocoding is the one we have looked at so far using an API endpoint.  It takes an address or a place name and returns the geographic coordinates of that location.  Let's look at it again using the Mapbox Python SDK.

# %%
from mapbox import Geocoder
import os

geocoder = Geocoder(access_token=my_api_key)

# %% [markdown]
# OK, now we can get to work on the geocoding... let's try geocoding Freehouse Restaurant, which is at 2700 Bancroft Way.

# %%
response = geocoder.forward('2700 Bancroft Way, Berkeley, CA 94704', limit=1)
data = response.json()
data
# Out:
# {'type': 'FeatureCollection',
#  'query': ['2700', 'bancroft', 'way', 'berkeley', 'ca', '94704'],
#  'features': [{'id': 'address.7730712976723886',
#    'type': 'Feature',
#    'place_type': ['address'],
#    'relevance': 1,
#    'properties': {'accuracy': 'parcel'},
#    'text': 'Bancroft Way',
#    'place_name': '2700 Bancroft Way, Berkeley, California 94704, United States',
#    'center': [-122.254267, 37.868965],
#    'geometry': {'type': 'Point', 'coordinates': [-122.254267, 37.868965]},
#    'address': '2700',
#    'context': [{'id': 'neighborhood.14897580184476970',
#      'text': 'South Campus'},
#     {'id': 'postcode.13849498828668840', 'text': '94704'},
#     {'id': 'place.9820619379990170',
#      'wikidata': 'Q484678',
#      'text': 'Berkeley'},
#     {'id': 'district.11187960009291250',
#      'wikidata': 'Q107146',
#      'text': 'Alameda County'},
#     {'id': 'region.9803118085738010',
#      'short_code': 'US-CA',
#      'wikidata': 'Q99',
#      'text': 'California'},
#     {'id': 'country.19678805456372290',
#      'wikidata': 'Q30',
#      'short_code': 'us',
#      'text': 'United States'}]}],
#  'attribution': 'NOTICE: © 2022 Mapbox and its suppliers. All rights reserved. Use of this data is subject to the Mapbox Terms of Service (https://www.mapbox.com/about/maps/). This response and the information it contains may not be retained. POI(s) provided by Foursquare.'}

# %% [markdown]
# Another random address to geocode:

# %%
response = geocoder.forward('120 East 13th Street, Manhattan, New York, New York 10003', limit = 1)
first = response.json()['features'][0]
print(first['place_name'])
print([coord for coord in first['geometry']['coordinates']])
# Out:
# 120 East 13th Street, New York, New York 10003, United States
# [-73.98893, 40.73295]

# %% [markdown]
# #### 3.2.4.2 Creating a dataframe from multiple API queries
#
# Can you think of a good way to write a loop to geocode those addresses and add them to a dataframe?  Let's try one way to do this.

# %%
import pandas as pd
data = pd.DataFrame(index=[], columns=['address','lat','lon'])

addrs = [
    '3028 Regent St., Berkeley, California, 94705',
    '1511 Julia St, Berkeley, California, 94703',
    '2700 Bancroft, Berkeley, California, 94704']

# %%
for i in range(len(addrs)):
    geoadress=geocoder.forward(addrs[i], limit = 1).geojson()['features'][0]['geometry']['coordinates']
    data.loc[i, 'address']=addrs[i]
    data.loc[i, 'lon']=geoadress[0]
    data.loc[i, 'lat']=geoadress[1]
data
# Out:
#                                         address        lat         lon
# 0  3028 Regent St., Berkeley, California, 94705   37.85393  -122.26662
# 1    1511 Julia St, Berkeley, California, 94703  37.854495  -122.27862
# 2    2700 Bancroft, Berkeley, California, 94704  37.868965 -122.254267

# %% [markdown]
# #### 3.2.4.3 Reverse Geocoding
#
# Reverse geocoding does what it sounds like. It takes coordinates and returns an address or other place type.  Options for place type include: country, region, postcode, district, place, locality, neighborhood, address,and poi.
#
# Let's start by using the coordinates of the address we just got from forward geocoding, and get the address back from reverse geocoding of those coordinates.

# %%
response = geocoder.reverse(lat=37.868965, lon=-122.254267)
features = response.geojson()['features']
features
# Out:
# [{'id': 'address.7730712976723886',
#   'type': 'Feature',
#   'place_type': ['address'],
#   'relevance': 1,
#   'properties': {'accuracy': 'parcel'},
#   'text': 'Bancroft Way',
#   'place_name': '2700 Bancroft Way, Berkeley, California 94704, United States',
#   'center': [-122.2542675, 37.868965],
#   'geometry': {'type': 'Point', 'coordinates': [-122.2542675, 37.868965]},
#   'address': '2700',
#   'context': [{'id': 'neighborhood.14897580184476970', 'text': 'South Campus'},
#    {'id': 'postcode.13849498828668840', 'text': '94704'},
#    {'id': 'place.9820619379990170', 'wikidata': 'Q484678', 'text': 'Berkeley'},
#    {'id': 'district.11187960009291250',
#     'wikidata': 'Q107146',
#     'text': 'Alameda County'},
#    {'id': 'region.9803118085738010',
#     'short_code': 'US-CA',
#     'wikidata': 'Q99',
#     'text': 'California'},
#    {'id': 'country.19678805456372290',
#     'wikidata': 'Q30',
#     'short_code': 'us',
#     'text': 'United States'}]},
#  {'id': 'neighborhood.14897580184476970',
#   'type': 'Feature',
#   'place_type': ['neighborhood'],
#   'relevance': 1,
#   'properties': {},
#   'text': 'South Campus',
#   'place_name': 'South Campus, Berkeley, California, United States',
#   'bbox': [-122.265991211, 37.864250183, -122.250457764, 37.869602203],
#   'center': [-122.2585, 37.8667],
#   'geometry': {'type': 'Point', 'coordinates': [-122.2585, 37.8667]},
#   'context': [{'id': 'postcode.13849498828668840', 'text': '94704'},
#    {'id': 'place.9820619379990170', 'wikidata': 'Q484678', 'text': 'Berkeley'},
#    {'id': 'district.11187960009291250',
#     'wikidata': 'Q107146',
#     'text': 'Alameda County'},
#    {'id': 'region.9803118085738010',
#     'short_code': 'US-CA',
#     'wikidata': 'Q99',
#     'text': 'California'},
#    {'id': 'country.19678805456372290',
#     'wikidata': 'Q30',
#     'short_code': 'us',
#     'text': 'United States'}]},
#  {'id': 'postcode.13849498828668840',
#   'type': 'Feature',
#   'place_type': ['postcode'],
#   'relevance': 1,
#   'properties': {},
#   'text': '94704',
#   'place_name': 'Berkeley, California 94704, United States',
#   'bbox': [-122.27405789, 37.859768015, -122.238420049, 37.881203815],
#   'center': [-122.26, 37.87],
#   'geometry': {'type': 'Point', 'coordinates': [-122.26, 37.87]},
#   'context': [{'id': 'place.9820619379990170',
#     'wikidata': 'Q484678',
#     'text': 'Berkeley'},
#    {'id': 'district.11187960009291250',
#     'wikidata': 'Q107146',
#     'text': 'Alameda County'},
#    {'id': 'region.9803118085738010',
#     'short_code': 'US-CA',
#     'wikidata': 'Q99',
#     'text': 'California'},
#    {'id': 'country.19678805456372290',
#     'wikidata': 'Q30',
#     'short_code': 'us',
#     'text': 'United States'}]},
#  {'id': 'place.9820619379990170',
#   'type': 'Feature',
#   'place_type': ['place'],
#   'relevance': 1,
#   'properties': {'wikidata': 'Q484678'},
#   'text': 'Berkeley',
#   'place_name': 'Berkeley, California, United States',
#   'bbox': [-122.327101938, 37.84596, -122.21355766, 37.920357393],
#   'center': [-122.2729, 37.8708],
#   'geometry': {'type': 'Point', 'coordinates': [-122.2729, 37.8708]},
#   'context': [{'id': 'district.11187960009291250',
#     'wikidata': 'Q107146',
#     'text': 'Alameda County'},
#    {'id': 'region.9803118085738010',
#     'short_code': 'US-CA',
#     'wikidata': 'Q99',
#     'text': 'California'},
#    {'id': 'country.19678805456372290',
#     'wikidata': 'Q30',
#     'short_code': 'us',
#     'text': 'United States'}]},
#  {'id': 'district.11187960009291250',
#   'type': 'Feature',
#   'place_type': ['district'],
#   'relevance': 1,
#   'properties': {'wikidata': 'Q107146'},
#   'text': 'Alameda County',
#   'place_name': 'Alameda County, California, United States',
#   'bbox': [-122.342665, 37.454186, -121.469214, 37.905824],
#   'center': [-121.91, 37.65],
#   'geometry': {'type': 'Point', 'coordinates': [-121.91, 37.65]},
#   'context': [{'id': 'region.9803118085738010',
#     'short_code': 'US-CA',
#     'wikidata': 'Q99',
#     'text': 'California'},
#    {'id': 'country.19678805456372290',
#     'wikidata': 'Q30',
#     'short_code': 'us',
#     'text': 'United States'}]},
#  {'id': 'region.9803118085738010',
#   'type': 'Feature',
#   'place_type': ['region'],
#   'relevance': 1,
#   'properties': {'short_code': 'US-CA', 'wikidata': 'Q99'},
#   'text': 'California',
#   'place_name': 'California, United States',
#   'bbox': [-124.514829293866,
#    32.5019647016422,
#    -114.131210004164,
#    42.0095039998439],
#   'center': [-119.699375153073, 37.0743595873],
#   'geometry': {'type': 'Point',
#    'coordinates': [-119.699375153073, 37.0743595873]},
#   'context': [{'id': 'country.19678805456372290',
#     'wikidata': 'Q30',
#     'short_code': 'us',
#     'text': 'United States'}]},
#  {'id': 'country.19678805456372290',
#   'type': 'Feature',
#   'place_type': ['country'],
#   'relevance': 1,
#   'properties': {'wikidata': 'Q30', 'short_code': 'us'},
#   'text': 'United States',
#   'place_name': 'United States',
#   'bbox': [-179.9, 18.8163608007951, -66.8847646185949, 71.4202919997506],
#   'center': [-97.9222112121185, 39.3812661305678],
#   'geometry': {'type': 'Point',
#    'coordinates': [-97.9222112121185, 39.3812661305678]}}]

# %%
for f in features:
    print('{place_type[0]}'.format(**f) + ':', '{place_name}'.format(**f))
# Out:
# address: 2700 Bancroft Way, Berkeley, California 94704, United States
# neighborhood: South Campus, Berkeley, California, United States
# postcode: Berkeley, California 94704, United States
# place: Berkeley, California, United States
# district: Alameda County, California, United States
# region: California, United States
# country: United States

# %% [markdown]
# ### Bonus Section: Getting Directions from Mapbox
#
# You can put in start and end locations and call the Mapbox directions API to get suggested directions as a sequence of coordinates you could plot on a map.

# %%
from mapbox import Directions
help(Directions)
# Out:
# Help on class Directions in module mapbox.services.directions:
#
# class Directions(mapbox.services.base.Service)
#  |  Directions(access_token=None, host=None, cache=None)
#  |
#  |  Access to the Directions v5 API.
#  |
#  |  Method resolution order:
#  |      Directions
#  |      mapbox.services.base.Service
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  directions(self, features, profile='mapbox/driving', alternatives=None, geometries=None, overview=None, steps=None, continue_straight=None, waypoint_snapping=None, annotations=None, language=None, **kwargs)
#  |      Request directions for waypoints encoded as GeoJSON features.
#  |
#  |      Parameters
#  |      ----------
#  |      features : iterable
#  |          An collection of GeoJSON features
#  |      profile : str
#  |          Name of a Mapbox profile such as 'mapbox.driving'
#  |      alternatives : bool
#  |          Whether to try to return alternative routes, default: False
#  |      geometries : string
#  |          Type of geometry returned (geojson, polyline, polyline6)
#  |      overview : string or False
#  |          Type of returned overview geometry: 'full', 'simplified',
#  |          or False
#  |      steps : bool
#  |          Whether to return steps and turn-by-turn instructions,
#  |          default: False
#  |      continue_straight : bool
#  |          Direction of travel when departing intermediate waypoints
#  |      radiuses : iterable of numbers or 'unlimited'
#  |          Must be same length as features
#  |      waypoint_snapping : list
#  |          Controls snapping of waypoints
#  |
#  |          The list is zipped with the features collection and must
#  |          have the same length. Elements of the list must be one of:
#  |
#  |          - A number (interpretted as a snapping radius)
#  |          - The string 'unlimited' (unlimited snapping radius)
#  |          - A 3-element tuple consisting of (radius, angle, range)
#  |          - None (no snapping parameters specified for that waypoint)
#  |      annotations : str
#  |          Whether or not to return additional metadata along the route
#  |
#  |          Possible values are: 'duration', 'distance', 'speed', and
#  |          'congestion'. Several annotations can be used by joining
#  |          them with ','.
#  |      language : str
#  |          Language of returned turn-by-turn text instructions,
#  |          default: 'en'
#  |
#  |      Returns
#  |      -------
#  |      requests.Response
#  |          The response object has a geojson() method for access to
#  |          the route(s) as a GeoJSON-like FeatureCollection
#  |          dictionary.
#  |
#  |  ----------------------------------------------------------------------
#  |  Readonly properties defined here:
#  |
#  |  baseuri
#  |      The service's base URI
#  |
#  |      Returns
#  |      -------
#  |      str
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  api_name = 'directions'
#  |
#  |  api_version = 'v5'
#  |
#  |  valid_annotations = ['duration', 'distance', 'speed']
#  |
#  |  valid_geom_encoding = ['geojson', 'polyline', 'polyline6']
#  |
#  |  valid_geom_overview = ['full', 'simplified', False]
#  |
#  |  valid_profiles = ['mapbox/driving', 'mapbox/driving-traffic', 'mapbox/...
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from mapbox.services.base.Service:
#  |
#  |  __init__(self, access_token=None, host=None, cache=None)
#  |      Constructs a Service object
#  |
#  |      This method should be overridden by subclasses.
#  |
#  |      Parameters
#  |      ----------
#  |      access_token : str
#  |          Mapbox access token string.
#  |      host : str, optional
#  |          Mapbox API host (advanced usage only).
#  |      cache : CacheControl cache instance (Dict or FileCache), optional
#  |          Optional caching, not generally needed.
#  |
#  |      Returns
#  |      -------
#  |      Service
#  |
#  |  handle_http_error(self, response, custom_messages=None, raise_for_status=False)
#  |      Converts service errors to Python exceptions
#  |
#  |      Parameters
#  |      ----------
#  |      response : requests.Response
#  |          A service response.
#  |      custom_messages : dict, optional
#  |          A mapping of custom exception messages to HTTP status codes.
#  |      raise_for_status : bool, optional
#  |          If True, the requests library provides Python exceptions.
#  |
#  |      Returns
#  |      -------
#  |      None
#  |
#  |  ----------------------------------------------------------------------
#  |  Readonly properties inherited from mapbox.services.base.Service:
#  |
#  |  username
#  |      The username in the service's access token
#  |
#  |      Returns
#  |      -------
#  |      str
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from mapbox.services.base.Service:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes inherited from mapbox.services.base.Service:
#  |
#  |  default_host = 'api.mapbox.com'

# %%
service = Directions()

origin = {
        'type': 'Feature',
        'properties': {'name': 'Portland, OR'},
        'geometry': {
        'type': 'Point',
        'coordinates': [-122.7282, 45.5801]}}
destination = {
    'type': 'Feature',
    'properties': {'name': 'Bend, OR'},
    'geometry': {
    'type': 'Point',
    'coordinates': [-121.3153, 44.0582]}}

# %%
response = service.directions([origin, destination],'mapbox/driving')
driving_routes = response.geojson()
driving_routes
# Out:
# ---------------------------------------------------------------------
# KeyError                            Traceback (most recent call last)
# Input In [39], in <cell line: 2>()
#       1 response = service.directions([origin, destination],'mapbox/driving')
# ----> 2 driving_routes = response.geojson()
#       3 driving_routes
#
# File ~/anaconda3/envs/cp255/lib/python3.9/site-packages/mapbox/services/directions.py:247, in Directions.directions.<locals>.geojson()
#     246 def geojson():
# --> 247     return self._geojson(resp.json(), geom_format=geometries)
#
# File ~/anaconda3/envs/cp255/lib/python3.9/site-packages/mapbox/services/directions.py:256, in Directions._geojson(self, data, geom_format)
#     251 def _geojson(self, data, geom_format=None):
#     252     fc = {
#     253         'type': 'FeatureCollection',
#     254         'features': []}
# --> 256     for route in data['routes']:
#     257         if geom_format == 'geojson':
#     258             geom = route['geometry']
#
# KeyError: 'routes'

# %%
# %%html
# <iframe style="border-radius:12px" src="https://open.spotify.com/embed/track/5kqMiwRHsewDj42jxMJSeW?utm_source=generator" width="40%" height="80" frameBorder="0" allowfullscreen="" allow="autoplay; clipboard-write; encrypted-media; fullscreen; picture-in-picture"></iframe>
# Out:
# <iframe style="border-radius:12px" src="https://open.spotify.com/embed/track/5kqMiwRHsewDj42jxMJSeW?utm_source=generator" width="40%" height="80" frameBorder="0" allowfullscreen="" allow="autoplay; clipboard-write; encrypted-media; fullscreen; picture-in-picture"></iframe>

# %% [markdown]
# ## 3.3 Geocoding with Nominatim

# %% [markdown]
# Open source rules! Nominatim is an open source geocoding platform that is managed by OpenStreetMap (I think). Try using the Nominatim API to geocode or reverse geocode some data of interest! You can find the Nominamtim docs [here](https://nominatim.org/release-docs/develop/api/Search/)
#
# Hint: whenever you're using an API for the first time, its always a good idea to start by trying to find some example queries in the documentation, and then tweaking them to meet your needs.

# %%
query_str = 'wurster hall'
url = "https://nominatim.openstreetmap.org/?addressdetails=1&q={0}&format=json&limit=1".format(query_str)
res = requests.get(url)

# %%
res.json()
# Out:
# [{'place_id': 283158268,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 6415953,
#   'boundingbox': ['37.870117', '37.8710312', '-122.2552795', '-122.25431'],
#   'lat': '37.8705723',
#   'lon': '-122.25489935163237',
#   'display_name': 'Bauer Wurster Hall, Wurster Courtyard, Southside, Berkeley, Alameda County, California, 94720-1076, United States',
#   'class': 'building',
#   'type': 'university',
#   'importance': 0.201,
#   'address': {'building': 'Bauer Wurster Hall',
#    'road': 'Wurster Courtyard',
#    'neighbourhood': 'Southside',
#    'city': 'Berkeley',
#    'county': 'Alameda County',
#    'state': 'California',
#    'postcode': '94720-1076',
#    'country': 'United States',
#    'country_code': 'us'}}]

# %% [markdown]
# ## 3.4. Reverse geocoding with the FCC API
#
# Let's load the Craigslist rental listings again and quickly clean it up using the same code we previously used:

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('data/bay.csv')

# clean price and neighborhood
df.price = df.price.str.strip('$').astype('float64')
df.neighborhood = df.neighborhood.str.strip().str.strip('(').str.strip(')')

# break out the date into month day year columns
df['month'] = df['date'].str.split().str[0]
df['day'] = df['date'].str.split().str[1].astype('int32')
df['year'] = df['date'].str.split().str[2].astype('int32')
del df['date']

# extract bedrooms and square footage
def clean_bdrm(value):

    if isinstance(value, str):
        end = value.find('br')

        if end == -1:
            return
        
        else:
            start = value.find('/') + 2
            return int(value[start:end])

    else:
        return
    
def clean_sqft(value):

    if isinstance(value, str):
        end = value.find('ft')
        
        if end == -1:
            return

        else:
            if value.find('br') == -1:
                start = value.find('/') + 2
            else:
                start = value.find('-') + 2

            return int(value[start:end])

    else:
        return
    
df['sqft'] = df['beds_sqft'].map(clean_sqft)
df['bedrooms'] = df['beds_sqft'].map(clean_bdrm)
df.head()
# Out:
#          neighborhood                                              title  \
# 0             bayview     Take A TOUR ON OUR ONE FURNISHED BEDROOM TODAY
# 1             bayview   Only walking distance to major shopping centers.
# 2             bayview  furnished - 1 Bedroom(s), 1 Bath(s), Air Condi...
# 3  financial district  *NEW* Beautiful, Upscale Condo in Historic Jac...
# 4   visitacion valley                                             楼上全层3房
#
#     price                 beds_sqft         pid   longitude subregion  \
# 0   950.0               / 1br -      4076905111 -122.396965        SF
# 1   950.0               / 1br -      4076901755 -122.396793        SF
# 2   950.0               / 1br -      4076899340 -122.397100        SF
# 3  3300.0      / 1br - 830ft² -      4067393707 -122.399747        SF
# 4  2000.0     / 3br - 1280ft² -      4076901071         NaN        SF
#
#                        link   latitude month  day  year    sqft  bedrooms
# 0  /sfc/apa/4076905111.html  37.761216   Sep   18  2013     NaN       1.0
# 1  /sfc/apa/4076901755.html  37.761080   Sep   18  2013     NaN       1.0
# 2  /sfc/apa/4076899340.html  37.762100   Sep   18  2013     NaN       1.0
# 3  /sfc/apa/4067393707.html  37.798108   Sep   18  2013   830.0       1.0
# 4  /sfc/apa/4076901071.html        NaN   Sep   18  2013  1280.0       3.0

# %% [markdown]
# And now let's use the FCC [Census Block Conversions API](https://geo.fcc.gov/api/census/) to turn lat/long into a block FIPS code. FIPS codes contain from left to right: the location's 2-digit state code, 3-digit county code, 6-digit census tract code, and 4-digit census block code (the first digit of which is the census block group code). With a FIPS code in hand, you can easily merge your data against Census records.
#
# Here's a sample API query to get you started:

# %%
lat = 37.761216
lon = -122.396965
url = 'https://geo.fcc.gov/api/census/block/find?latitude={0}&longitude={1}&format=json'.format(lat, lon)
response = requests.get(url)
data = response.json()
data
# Out:
# {'messages': ["FCC0001: The coordinate lies on the boundary of mulitple blocks, the block contains the clicked location is selected. For a complete list use showall=true to display 'intersection' element in the Block"],
#  'Block': {'FIPS': '060750227022007',
#   'bbox': [-122.397372, 37.759967, -122.396284, 37.7613]},
#  'County': {'FIPS': '06075', 'name': 'San Francisco County'},
#  'State': {'FIPS': '06', 'code': 'CA', 'name': 'California'},
#  'status': 'OK',
#  'executionTime': '0'}

# %% [markdown]
# ## 3.5. Exercise
#
# Your job now is to write some Python code to get the FIPS code for every row in the Craigslist rental data, and store that FIPS code as a new column in the dataframe. You might consider using [`df.iterrows()`](http://pandas.pydata.org/pandas-docs/dev/generated/pandas.DataFrame.iterrows.html) to loop through each row of the dataframe one at a time, or if you're feeling fancy, you could define a function and use a vectorized approach (e.g. `df.apply()` or `df.map()`) to run the function on each row of your dataframe without any loops at all!
#
# **CAUTION: PLEASE DO NOT RUN THIS IN CLASS!!!** If we are all doing this at the same time on the same internet connection, you might get our IP address blacklisted by querying the API too many times.
#
# A few tips:
# - Since the API is SLOW for processing a lot of records, and works one record at a time, test out your code using only a few records until you are positive you have it working correctly. It may take several minutes to grind through all the records. You might want to print the row you are processing...maybe every 10th row, to give you some sense of how it is progressing.
# - Watch out for those missing lat-longs. You'll probably want to skip them since the API won't know what to do with them.
# - Consider adding some conditional logic to handle failed HTTP requests. This will prevent you from having to start your iteration over every time your program encounters an error

# %% [markdown]
# # 4. The Census API

# %% [markdown]
# Whatever "Urban Informatics" is or isn't, more often than not you'll find it useful to refer to census data. In this course, we'll be looking at capital-C Census data, i.e. the US Census, if for no other reason than the fact that it is being taught at UC Berkeley which happens to be located in California which happens to be located in the United States. Also, US Census data rocks!
#
# **Question**: Does anyone know of other countries that have good, publically available census data?

# %% [markdown]
# The US Census provides API endpoints for most of its public data. You can find a list of them, along with links to their documentation, [here](https://www.census.gov/data/developers/data-sets.html).
#
# You can use those endpoints to construct your own custom queries and get the data you want by sending HTTP requests to those URLs. For example, to get the total population from 2018 in Alameda County, you can do:

# %%
# define parameters of our API query
acs_var = 'B01001_001E'  # total pop
state = '06'  # CA
counties = ['001', '075']  # Alameda and SF
year = 2018

# format the URL
counties_str = ','.join(counties)
url = "https://api.census.gov/data/{0}/acs/acs5?get={1}&for=county:{2}&in=state:{3}".format(
    year, acs_var, counties_str, state)

# execute the HTTP request
res = requests.get(url)
pd.DataFrame(res.json())
# Out:
#              0      1       2
# 0  B01001_001E  state  county
# 1       870044     06     075
# 2      1643700     06     001

# %% [markdown]
# ## 4.1. Getting a Census API key
# A word of warning. These Census API queries may or may not work for you without specifying an API key. It's probably a good idea to get one anyways, because you will eventually be asked for it after enough queries. You can do that [here](https://api.census.gov/data/key_signup.html)

# %% [markdown]
# ## 4.2. Census API Python Library

# %% [markdown]
# One of the great things about working with open source software and open data is that people are publishing useful tools all the time that you can use to make your life easier. In the case of Census data, there are multiple Python libraries to choose from which are designed to make it a little easier to interact with the Census API.
#
# We'll focus on one that's simply called [census](https://github.com/datamade/census). You _will_ need a Census API key to use this package.
#
# Use the instructions on that GitHub repo to use `pip` to install the `census` package, along with its sister package `us`.

# %%
from census import Census
from us import states

# I store my API key stored as an environment variable rather than a .json file
census_key = os.getenv("CENSUS_API")  

c = Census(census_key, year=year)
res = c.acs5.get((
    'NAME', acs_var), {
    'for': 'county:{}'.format(counties_str),
    'in': 'state:{}'.format(states.CA.fips)
})

pd.DataFrame(res)
# Out:
#                                NAME  B01001_001E state county
# 0  San Francisco County, California     870044.0    06    075
# 1        Alameda County, California    1643700.0    06    001

# %%
acs_df = pd.DataFrame()

for year in range(2010, 2018):
    c = Census(census_key, year=year)
    res = c.acs1.get((
        'NAME', acs_var), {
        'for': 'county:{}'.format(counties_str),
        'in': 'state:{}'.format(states.CA.fips)
    })

    year_df = pd.DataFrame(res)
    year_df['year'] = year
    acs_df = pd.concat((acs_df, year_df), ignore_index=True)

# %%
import seaborn as sns
sns.lineplot(data=acs_df, x='year', y=acs_var, hue='NAME')
# Out:
# <AxesSubplot:xlabel='year', ylabel='B01001_001E'>

# %% [markdown]
# ## 4.3 More exercises!
#
# Your turn:
# 1. Look up the latitude and longitude of your home address using forward geocoding
# 2. Use the latitude and longitude from that to get the census block of your home address
# 3. Challenge problem: create a dataframe with 3 street addresses and a description column with labels for these locations, and write code that will iterate through them, get the latitude and longitude for each, and the FIPS block code, County name, and write these addresses, lat and long, and FIPS Block code and County names to a dataframe.

# %%
# %%html
# <iframe style="border-radius:12px" src="https://open.spotify.com/embed/track/4KBULZasCMBDKHY8IPUCML?utm_source=generator" width="40%" height="80" frameBorder="0" allowfullscreen="" allow="autoplay; clipboard-write; encrypted-media; fullscreen; picture-in-picture"></iframe>
# Out:
# <iframe style="border-radius:12px" src="https://open.spotify.com/embed/track/4KBULZasCMBDKHY8IPUCML?utm_source=generator" width="40%" height="80" frameBorder="0" allowfullscreen="" allow="autoplay; clipboard-write; encrypted-media; fullscreen; picture-in-picture"></iframe>

# %% [markdown]
# # 5. Summary

# %% [markdown]
# By this point in the class you have all the tools you need to:
# 1. find interesting data sets
# 1. load them into Python
# 1. explore, clean, and manipulate that data
# 1. combine it with external administrative or demographic data from the Census
# 1. create charts and visualizations to communicate your findings
# 1. save your new data to disk so you can come back to it later

# %% [markdown]
# # 6. For next time

# %% [markdown]
# - We're about to enter my favorite module of this course: **Working with Geospatial Data**. Some of you have considerable experience with GIS already, and are very comfortable with concepts like coordinate reference systems and map projections, and how to deal with these when working with spatial data.  If so, you might not need to spend much time with the readings for next session, but if not, please at least familiarize yourself with the material from the first two links on the syllabus:
#   - [mapschool.io](https://mapschool.io/)
#   - Part I of [Geographic Data Science with Python](https://geographicdata.science/book/notebooks/00_toc.html)
#
# - We will also be using the GeoPandas Python library, so browse the documentation [here](http://geopandas.org/) and install it ahead of time.
# - Work through the exercises in this notebook that you didn't get through in class

# %% [markdown]
# # 7. Questions?

# %% [markdown]
# # Sources
#
# This notebook was heavily adapted from previous course material by [Prof. Paul Waddell](https://urbansim.com/people) and [Samuel Maurer](http://samuelmaurer.info/).
